# %%
# !pip install pytorch-metric-learning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-metric-learning
#   Downloading pytorch_metric_learning-2.1.1-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->pytorch-metric-learning) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->pytorch-metric-learning) (16.0.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->pytorch-metric-learning) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->pytorch-metric-learning) (1.3.0)
# Installing collected packages: pytorch-metric-learning
# Successfully installed pytorch-metric-learning-2.1.1

# %%
import os
import json
import zipfile
import subprocess
import shutil
import getpass
import math
import numpy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image,ImageReadMode
import matplotlib.pyplot as plt
from pytorch_metric_learning import losses, regularizers
from torchsummary import summary

# %%
torch.manual_seed(20)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
# device = "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
dataset_save_dir = './dataset'

# %%
def one_hot_encode(val):
    arr = numpy.zeros((6,), dtype=int)
    arr[val] = 1
    return arr

def get_bucket_id(age):
  age_floor = int(age)
  if age_floor >= 0 and age_floor <= 5: return 0
  elif age_floor >= 6 and age_floor <= 12: return 1
  elif age_floor >= 13 and age_floor <= 19: return 2
  elif age_floor >= 20 and age_floor <= 29: return 3
  elif age_floor >= 30 and age_floor <= 59: return 4
  else: return 5

def get_ground_truth(age):
  return one_hot_encode(get_bucket_id(age))

# %%
def get_random_two_different_int(low=0, high=6, size=1):
  num1 = torch.randint(low,high, (size,)).item()
  num2 = torch.randint(low,high, (size,)).item()
  while num1 == num2: num2 = torch.randint(low,high, (size,)).item()
  return num1,num2

# %%
def train(dataloader, model, loss_fn, optimizer):
    torch.cuda.empty_cache()
    size = len(dataloader.dataset)
    model.train()
    loss_tot = 0.0
    num = 0
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        embeddings = model.forward_once(X)
        pairwise_distances = torch.cdist(embeddings,embeddings)

        # Find triplets
        triplets = []
        embedding_anchor = []
        embedding_pos = []
        embedding_neg = []
        batch_size = embeddings.size(0)
        embedding_dim = embeddings.size(1)

        for i in range(batch_size):
            label_i = y[i]
            positive_indices = torch.where(y == label_i)[0]
            negative_indices = torch.where(y != label_i)[0]
            farthest_pos_index = positive_indices[torch.argmax(pairwise_distances[i][positive_indices])]
            nearest_neg_index = negative_indices[torch.argmin(pairwise_distances[i][negative_indices])]
            embedding_anchor.append(embeddings[i])
            embedding_pos.append(embeddings[farthest_pos_index])
            embedding_neg.append(embeddings[nearest_neg_index])

        embedding_anchor = torch.stack(embedding_anchor, dim=0)
        embedding_pos = torch.stack(embedding_pos, dim=0)
        embedding_neg = torch.stack(embedding_neg, dim=0)

        # Forward
        optimizer.zero_grad()
        ea, ep, en = model.forward_only_fc(embedding_anchor, embedding_pos, embedding_neg)
    
        loss = loss_fn(ea, ep, en)
        loss.backward()
        optimizer.step()

        loss_tot += loss.item()
        num += 1

        X.cpu()
        y.cpu()

        # Gather data and report
        if batch % 4 == 0:
            current = (batch + 1) * len(X)
            print(f"loss: {loss.item():>7f}  [{current:>5d}/{size:>5d}]")

    # loss_tot /= num
    print(f'training loss: {(loss_tot):>0.5f}')

# %%
validation_accuracy = []
current_max_val_acc = 0.0
def validation(dataloader, model, loss_fn):
    global current_max_val_acc
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    correct = 0
    totalsize = 0
    loss_tot = 0.0
    num = 0
    with torch.no_grad():
        for batch, (X, y) in enumerate(dataloader):
            X, y = X.to(device), y.to(device)

            embeddings = model.forward_once(X)
            pairwise_distances = torch.cdist(embeddings,embeddings)

            # Find triplets
            triplets = []
            embedding_anchor = []
            embedding_pos = []
            embedding_neg = []
            batch_size = embeddings.size(0)
            embedding_dim = embeddings.size(1)

            for i in range(batch_size):
                label_i = y[i]
                positive_indices = torch.where(y == label_i)[0]
                negative_indices = torch.where(y != label_i)[0]
                farthest_pos_index = positive_indices[torch.argmax(pairwise_distances[i][positive_indices])]
                nearest_neg_index = negative_indices[torch.argmin(pairwise_distances[i][negative_indices])]
                embedding_anchor.append(embeddings[i])
                embedding_pos.append(embeddings[farthest_pos_index])
                embedding_neg.append(embeddings[nearest_neg_index])

            embedding_anchor = torch.stack(embedding_anchor, dim=0)
            embedding_pos = torch.stack(embedding_pos, dim=0)
            embedding_neg = torch.stack(embedding_neg, dim=0)

            # Forward
            ea, ep, en = model.forward_only_fc(embedding_anchor, embedding_pos, embedding_neg)
            
            distances = torch.nn.functional.pairwise_distance(ea, en) - torch.nn.functional.pairwise_distance(ea, ep)
            predictions = (distances >= 0).float()

            correct += torch.sum(predictions).item()
            totalsize += ea.shape[0]

            loss = loss_fn(ea, ep, en)

            loss_tot += loss.item()

            X.cpu()
            y.cpu()
            
    print(f"Correct/Total: {correct}/{totalsize}")
    correct /= totalsize
    validation_accuracy.append(correct*100)
    print(f"Validation Loss:  {(loss_tot):>0.5f}")
    print(f"Validation Accuracy: {(100*correct):>0.5f}%\n")
    current_max_val_acc = max(current_max_val_acc,100*correct)
    print(f"Current Best Validation Accuracy: {(current_max_val_acc):>0.5f}%\n")
    return loss_tot

# %%
data_augmentation_transformations = T.RandomChoice([ # Geometric Transformation
    T.RandomAffine(degrees=0),
    T.Lambda(lambda x: TF.hflip(img=x))
    # T.RandomAffine(degrees=0), # No Transformation
    # Geometric Transformations:
    # T.RandomAffine(degrees=0, scale=(1.3,1.3)), # Scale
    # T.RandomAffine(degrees=0, translate=(0.5,0.5)), # Translate
    # T.RandomAffine(degrees=(-8, 8)), # Rotate
    # T.Lambda(lambda x: TF.hflip(img=x)), # Reflect
    # Skipping Shearing & Skewing as they don't make sense in this context of Teeth X-Ray
    # Occlusion:
    # T.Compose([T.RandomErasing(p=1, scale=(0.0008, 0.0008), ratio=(1,1))]*100), # Occlusion
    # T.Compose([T.RandomErasing(p=1, scale=(0.0008, 0.0008), ratio=(1,1))]*100), # Occlusion
    # T.Compose([T.RandomErasing(p=1, scale=(0.0008, 0.0008), ratio=(1,1))]*100), # Occlusion
    # Intensity Operations
    # T.Lambda(lambda x: TF.adjust_gamma(img=x, gamma=0.5)), # Gamma Contrast
    # T.Lambda(lambda x: TF.adjust_contrast(x, contrast_factor=2.0)), # Linear Contrast
    # Histogram Equalizer skipped as we need to typecast it to uint8 for that
    # Skipping Noise injection as we want to easily normalize it later 
    # Filtering:
    # T.Lambda(lambda x: TF.adjust_sharpness(img=x, sharpness_factor=4)), #Sharpen
    # T.GaussianBlur(kernel_size=(15,15), sigma=(0.01, 1)), # Gaussian Blur
])

# %%
class XRayToothDataset(Dataset):
    def __init__(self, cwd, img_dir, transform=None, target_height=None, target_width=None):
        self.dataset_path = cwd + '/' + img_dir
        self.transform = transform
        self.target_height = target_height
        self.target_width = target_width

    def __len__(self):
        return len(os.listdir(self.dataset_path))

    def __getitem__(self, idx):
        if idx  >= len(os.listdir(self.dataset_path)):
            print("No datafile/image at index : "+ str(idx))
            return None
        img_filename = os.listdir(self.dataset_path)[idx]
        age = float(img_filename.split("_")[1][:-4])
        age_gt = get_bucket_id(age)
        image_tensor = read_image(path=self.dataset_path + '/' + img_filename)
        image_tensor = image_tensor.reshape(1, 3, image_tensor.shape[-2], image_tensor.shape[-1])
        if self.target_height and self.target_width: # Resize the image 
            image_tensor = torch.nn.functional.interpolate(image_tensor, (self.target_height,self.target_width))
        if self.transform: image_tensor = self.transform(image_tensor) # Apply transformations
        image_tensor = (image_tensor-image_tensor.min())/(image_tensor.max()-image_tensor.min())
        return image_tensor.reshape(-1,image_tensor.shape[-2],image_tensor.shape[-1]).to(torch.float32), torch.tensor(age_gt)

# %%
training_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/training', transform=data_augmentation_transformations, target_height=224, target_width=224)
validation_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/validation', transform=None, target_height=224, target_width=224)

# %%
from torchvision.models import vit_l_32, ViT_L_32_Weights

pretrained_vit = vit_l_32(weights=ViT_L_32_Weights.IMAGENET1K_V1)
# Out:
# Downloading: "https://download.pytorch.org/models/vit_l_32-c7638314.pth" to /root/.cache/torch/hub/checkpoints/vit_l_32-c7638314.pth
# 100%|██████████| 1.14G/1.14G [00:16<00:00, 74.4MB/s]

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = pretrained_vit

        for param in self.backbone.parameters():
            param.requires_grad = False

        self.fc = nn.Sequential(
            nn.Dropout(0.6),
            nn.Linear(1000,6)
        )

    def forward_once(self, x):
        x = self.backbone(x)
        return x
    
    def forward_only_fc(self, ea, ep, en):
        ea = self.fc(ea)
        ep = self.fc(ep)
        en = self.fc(en)
        
        return ea, ep, en
    
    def forward(self, xA, xP, xN):
        ea = self.fc(self.forward_once(xA))
        ep = self.fc(self.forward_once(xP))
        en = self.fc(self.forward_once(xN))
        
        return ea, ep, en

# %%
model = NeuralNetwork().to(device)

# %%
# Training Hyperparameters
epochs = 500
batch_size = 50
learning_rate = 1e-2
momentum=0.9
weight_decay=0.05

# %%
training_data_loader = DataLoader(training_data, batch_size, shuffle = True)
validation_data_loader = DataLoader(validation_data, batch_size, shuffle = False)

# %%
loss_function=nn.TripletMarginLoss()
optimizer=torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=5, min_lr=1e-4,verbose=True)

# %%
# Training
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data_loader, model, loss_function, optimizer)
    val_loss = validation(validation_data_loader, model, loss_function)
    scheduler.step(val_loss)
    # torch.save(model, 'model.pth')
print("Done!")
# Out:
# Streaming output truncated to the last 5000 lines.
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 48
# -------------------------------
# loss: 0.848840  [   50/  296]
# loss: 1.065022  [  250/  296]
# training loss: 5.49475
# Correct/Total: 57.0/129
# Validation Loss:  3.60195
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 49
# -------------------------------
# loss: 0.851038  [   50/  296]
# loss: 1.058943  [  250/  296]
# training loss: 5.42483
# Correct/Total: 58.0/129
# Validation Loss:  3.64971
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 00249: reducing learning rate of group 0 to 3.0903e-04.
# Epoch 50
# -------------------------------
# loss: 0.897987  [   50/  296]
# loss: 0.846823  [  250/  296]
# training loss: 5.34264
# Correct/Total: 58.0/129
# Validation Loss:  3.66352
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 51
# -------------------------------
# loss: 0.606697  [   50/  296]
# loss: 0.648479  [  250/  296]
# training loss: 5.12523
# Correct/Total: 58.0/129
# Validation Loss:  3.66714
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 52
# -------------------------------
# loss: 0.636762  [   50/  296]
# loss: 0.982716  [  250/  296]
# training loss: 4.78860
# Correct/Total: 58.0/129
# Validation Loss:  3.66131
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 53
# -------------------------------
# loss: 0.920285  [   50/  296]
# loss: 0.767652  [  250/  296]
# training loss: 5.28884
# Correct/Total: 58.0/129
# Validation Loss:  3.65716
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 54
# -------------------------------
# loss: 0.870730  [   50/  296]
# loss: 0.730641  [  250/  296]
# training loss: 5.21860
# Correct/Total: 59.0/129
# Validation Loss:  3.65785
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 55
# -------------------------------
# loss: 0.954109  [   50/  296]
# loss: 0.677448  [  250/  296]
# training loss: 4.81751
# Correct/Total: 58.0/129
# Validation Loss:  3.65470
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 00255: reducing learning rate of group 0 to 2.7813e-04.
# Epoch 56
# -------------------------------
# loss: 1.064486  [   50/  296]
# loss: 0.827201  [  250/  296]
# training loss: 5.36611
# Correct/Total: 58.0/129
# Validation Loss:  3.64645
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 57
# -------------------------------
# loss: 0.729019  [   50/  296]
# loss: 0.670503  [  250/  296]
# training loss: 4.98716
# Correct/Total: 58.0/129
# Validation Loss:  3.65107
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 58
# -------------------------------
# loss: 0.768691  [   50/  296]
# loss: 0.874546  [  250/  296]
# training loss: 5.02223
# Correct/Total: 59.0/129
# Validation Loss:  3.65297
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 59
# -------------------------------
# loss: 0.905105  [   50/  296]
# loss: 0.571361  [  250/  296]
# training loss: 4.62518
# Correct/Total: 58.0/129
# Validation Loss:  3.66271
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 60
# -------------------------------
# loss: 0.882128  [   50/  296]
# loss: 0.843570  [  250/  296]
# training loss: 4.87308
# Correct/Total: 59.0/129
# Validation Loss:  3.67565
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 61
# -------------------------------
# loss: 0.685678  [   50/  296]
# loss: 1.022444  [  250/  296]
# training loss: 4.88879
# Correct/Total: 58.0/129
# Validation Loss:  3.69695
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 00261: reducing learning rate of group 0 to 2.5032e-04.
# Epoch 62
# -------------------------------
# loss: 0.991733  [   50/  296]
# loss: 0.882430  [  250/  296]
# training loss: 5.43589
# Correct/Total: 57.0/129
# Validation Loss:  3.71196
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 63
# -------------------------------
# loss: 1.100825  [   50/  296]
# loss: 0.754274  [  250/  296]
# training loss: 5.08504
# Correct/Total: 58.0/129
# Validation Loss:  3.72451
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 64
# -------------------------------
# loss: 0.742744  [   50/  296]
# loss: 0.642043  [  250/  296]
# training loss: 4.64136
# Correct/Total: 58.0/129
# Validation Loss:  3.73105
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 65
# -------------------------------
# loss: 0.667778  [   50/  296]
# loss: 0.743226  [  250/  296]
# training loss: 4.45173
# Correct/Total: 57.0/129
# Validation Loss:  3.72741
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 66
# -------------------------------
# loss: 0.983679  [   50/  296]
# loss: 0.841620  [  250/  296]
# training loss: 5.48021
# Correct/Total: 57.0/129
# Validation Loss:  3.70344
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 67
# -------------------------------
# loss: 0.797521  [   50/  296]
# loss: 0.784180  [  250/  296]
# training loss: 4.84779
# Correct/Total: 56.0/129
# Validation Loss:  3.69867
# Validation Accuracy: 43.41085%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 00267: reducing learning rate of group 0 to 2.2528e-04.
# Epoch 68
# -------------------------------
# loss: 0.675603  [   50/  296]
# loss: 0.728456  [  250/  296]
# training loss: 4.68557
# Correct/Total: 55.0/129
# Validation Loss:  3.69563
# Validation Accuracy: 42.63566%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 69
# -------------------------------
# loss: 0.823402  [   50/  296]
# loss: 0.783662  [  250/  296]
# training loss: 5.42283
# Correct/Total: 56.0/129
# Validation Loss:  3.69590
# Validation Accuracy: 43.41085%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 70
# -------------------------------
# loss: 0.870460  [   50/  296]
# loss: 0.864808  [  250/  296]
# training loss: 5.43500
# Correct/Total: 57.0/129
# Validation Loss:  3.68787
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 71
# -------------------------------
# loss: 0.619274  [   50/  296]
# loss: 0.648848  [  250/  296]
# training loss: 4.67364
# Correct/Total: 58.0/129
# Validation Loss:  3.66646
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 72
# -------------------------------
# loss: 0.725370  [   50/  296]
# loss: 0.953669  [  250/  296]
# training loss: 4.98281
# Correct/Total: 58.0/129
# Validation Loss:  3.65127
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 73
# -------------------------------
# loss: 0.657656  [   50/  296]
# loss: 1.004277  [  250/  296]
# training loss: 5.38121
# Correct/Total: 58.0/129
# Validation Loss:  3.64044
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 00273: reducing learning rate of group 0 to 2.0276e-04.
# Epoch 74
# -------------------------------
# loss: 0.891644  [   50/  296]
# loss: 0.831764  [  250/  296]
# training loss: 4.44792
# Correct/Total: 57.0/129
# Validation Loss:  3.63624
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 75
# -------------------------------
# loss: 0.581125  [   50/  296]
# loss: 0.663050  [  250/  296]
# training loss: 4.48104
# Correct/Total: 57.0/129
# Validation Loss:  3.62525
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 76
# -------------------------------
# loss: 0.845004  [   50/  296]
# loss: 0.650127  [  250/  296]
# training loss: 5.23229
# Correct/Total: 57.0/129
# Validation Loss:  3.63267
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 77
# -------------------------------
# loss: 0.664289  [   50/  296]
# loss: 0.864170  [  250/  296]
# training loss: 5.19579
# Correct/Total: 56.0/129
# Validation Loss:  3.64457
# Validation Accuracy: 43.41085%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 78
# -------------------------------
# loss: 0.899248  [   50/  296]
# loss: 0.772927  [  250/  296]
# training loss: 4.73384
# Correct/Total: 57.0/129
# Validation Loss:  3.64871
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 79
# -------------------------------
# loss: 0.958892  [   50/  296]
# loss: 0.728614  [  250/  296]
# training loss: 5.23097
# Correct/Total: 57.0/129
# Validation Loss:  3.66713
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 00279: reducing learning rate of group 0 to 1.8248e-04.
# Epoch 80
# -------------------------------
# loss: 0.905893  [   50/  296]
# loss: 1.006983  [  250/  296]
# training loss: 4.93328
# Correct/Total: 57.0/129
# Validation Loss:  3.68348
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 81
# -------------------------------
# loss: 1.038725  [   50/  296]
# loss: 0.639335  [  250/  296]
# training loss: 4.52811
# Correct/Total: 57.0/129
# Validation Loss:  3.69859
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 82
# -------------------------------
# loss: 0.888601  [   50/  296]
# loss: 1.015520  [  250/  296]
# training loss: 5.42117
# Correct/Total: 57.0/129
# Validation Loss:  3.70123
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 83
# -------------------------------
# loss: 0.650390  [   50/  296]
# loss: 0.610293  [  250/  296]
# training loss: 4.45345
# Correct/Total: 58.0/129
# Validation Loss:  3.71767
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 84
# -------------------------------
# loss: 0.821507  [   50/  296]
# loss: 0.537182  [  250/  296]
# training loss: 4.69356
# Correct/Total: 58.0/129
# Validation Loss:  3.72952
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 85
# -------------------------------
# loss: 0.692532  [   50/  296]
# loss: 0.843502  [  250/  296]
# training loss: 4.47088
# Correct/Total: 58.0/129
# Validation Loss:  3.72812
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 00285: reducing learning rate of group 0 to 1.6423e-04.
# Epoch 86
# -------------------------------
# loss: 0.814003  [   50/  296]
# loss: 0.846901  [  250/  296]
# training loss: 4.83835
# Correct/Total: 58.0/129
# Validation Loss:  3.73123
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 87
# -------------------------------
# loss: 0.819184  [   50/  296]
# loss: 1.016775  [  250/  296]
# training loss: 5.04544
# Correct/Total: 58.0/129
# Validation Loss:  3.73717
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 88
# -------------------------------
# loss: 0.850887  [   50/  296]
# loss: 0.541692  [  250/  296]
# training loss: 4.26412
# Correct/Total: 57.0/129
# Validation Loss:  3.73403
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 89
# -------------------------------
# loss: 0.811376  [   50/  296]
# loss: 0.863612  [  250/  296]
# training loss: 5.17585
# Correct/Total: 58.0/129
# Validation Loss:  3.73131
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 90
# -------------------------------
# loss: 0.681825  [   50/  296]
# loss: 0.601805  [  250/  296]
# training loss: 4.28481
# Correct/Total: 59.0/129
# Validation Loss:  3.72150
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 91
# -------------------------------
# loss: 0.692998  [   50/  296]
# loss: 0.644319  [  250/  296]
# training loss: 4.58112
# Correct/Total: 59.0/129
# Validation Loss:  3.72505
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 00291: reducing learning rate of group 0 to 1.4781e-04.
# Epoch 92
# -------------------------------
# loss: 0.629933  [   50/  296]
# loss: 0.681206  [  250/  296]
# training loss: 4.71094
# Correct/Total: 59.0/129
# Validation Loss:  3.73043
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch 93
# -------------------------------
# loss: 0.729427  [   50/  296]
# loss: 0.960286  [  250/  296]
# training loss: 4.52125
# Correct/Total: 58.0/129
# Validation Loss:  3.73796
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 47.28682%
#
# Epoch
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 485
# -------------------------------
# loss: 0.798276  [   50/  296]
# loss: 0.651857  [  250/  296]
# training loss: 4.11208
# Correct/Total: 60.0/129
# Validation Loss:  3.40552
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 486
# -------------------------------
# loss: 0.557724  [   50/  296]
# loss: 0.657783  [  250/  296]
# training loss: 4.00648
# Correct/Total: 60.0/129
# Validation Loss:  3.40806
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 487
# -------------------------------
# loss: 0.380653  [   50/  296]
# loss: 0.921028  [  250/  296]
# training loss: 4.14460
# Correct/Total: 60.0/129
# Validation Loss:  3.40772
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 488
# -------------------------------
# loss: 0.744872  [   50/  296]
# loss: 0.650516  [  250/  296]
# training loss: 3.96132
# Correct/Total: 60.0/129
# Validation Loss:  3.40967
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 489
# -------------------------------
# loss: 0.757879  [   50/  296]
# loss: 0.651153  [  250/  296]
# training loss: 4.59045
# Correct/Total: 60.0/129
# Validation Loss:  3.41150
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 490
# -------------------------------
# loss: 0.763177  [   50/  296]
# loss: 0.655704  [  250/  296]
# training loss: 4.12476
# Correct/Total: 60.0/129
# Validation Loss:  3.40957
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 491
# -------------------------------
# loss: 0.548188  [   50/  296]
# loss: 0.678759  [  250/  296]
# training loss: 4.61592
# Correct/Total: 60.0/129
# Validation Loss:  3.41715
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 492
# -------------------------------
# loss: 0.602124  [   50/  296]
# loss: 0.586791  [  250/  296]
# training loss: 3.99074
# Correct/Total: 60.0/129
# Validation Loss:  3.42270
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 493
# -------------------------------
# loss: 0.663880  [   50/  296]
# loss: 0.658276  [  250/  296]
# training loss: 3.73498
# Correct/Total: 60.0/129
# Validation Loss:  3.42293
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 494
# -------------------------------
# loss: 0.656741  [   50/  296]
# loss: 0.649884  [  250/  296]
# training loss: 4.10383
# Correct/Total: 60.0/129
# Validation Loss:  3.42166
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 495
# -------------------------------
# loss: 0.556756  [   50/  296]
# loss: 0.816059  [  250/  296]
# training loss: 4.31141
# Correct/Total: 60.0/129
# Validation Loss:  3.42534
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 496
# -------------------------------
# loss: 0.848785  [   50/  296]
# loss: 0.518568  [  250/  296]
# training loss: 3.96385
# Correct/Total: 59.0/129
# Validation Loss:  3.43381
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 497
# -------------------------------
# loss: 0.680507  [   50/  296]
# loss: 0.646583  [  250/  296]
# training loss: 4.59395
# Correct/Total: 60.0/129
# Validation Loss:  3.44152
# Validation Accuracy: 46.51163%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 498
# -------------------------------
# loss: 0.785606  [   50/  296]
# loss: 0.874091  [  250/  296]
# training loss: 4.43987
# Correct/Total: 59.0/129
# Validation Loss:  3.44807
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 499
# -------------------------------
# loss: 0.583180  [   50/  296]
# loss: 0.912359  [  250/  296]
# training loss: 4.38006
# Correct/Total: 58.0/129
# Validation Loss:  3.45152
# Validation Accuracy: 44.96124%
#
# Current Best Validation Accuracy: 48.06202%
#
# Epoch 500
# -------------------------------
# loss: 0.679751  [   50/  296]
# loss: 0.789087  [  250/  296]
# training loss: 4.61131
# Correct/Total: 59.0/129
# Validation Loss:  3.44981
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 48.06202%
#
# Done!

# %%
plt.plot(validation_accuracy)
