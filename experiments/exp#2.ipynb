# %%
import os
import json
import zipfile
import subprocess
import shutil
import getpass
import math
import numpy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image,ImageReadMode
import matplotlib.pyplot as plt

# %%
torch.manual_seed(20)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
# device = "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
dataset_save_dir = './dataset'

# %%
def one_hot_encode(val):
    arr = numpy.zeros((6,), dtype=int)
    arr[val] = 1
    return arr

def get_bucket_id(age):
  age_floor = int(age)
  if age_floor >= 0 and age_floor <= 5: return 0
  elif age_floor >= 6 and age_floor <= 12: return 1
  elif age_floor >= 13 and age_floor <= 19: return 2
  elif age_floor >= 20 and age_floor <= 29: return 3
  elif age_floor >= 30 and age_floor <= 59: return 4
  else: return 5

def get_ground_truth(age):
  return one_hot_encode(get_bucket_id(age))

# %%
def train(dataloader, model, loss_fn, optimizer):
    torch.cuda.empty_cache()
    size = len(dataloader.dataset)
    model.train()
    loss_tot = 0.0
    num = 0
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
      
        # Forward
        pred = model(X)
        # predSoftmax = nn.Softmax(dim=1)(pred)
        loss = loss_fn(pred,y)

        # print(loss.item())

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_tot += loss.item()
        num += 1
        
        X.cpu()
        y.cpu()

    # loss_tot /= num
    print(f'training loss: {(loss_tot):>0.5f}')

# %%
validation_accuracy = []
current_max_val_acc = 0.0
def validation(dataloader, model, loss_fn):
    global current_max_val_acc
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    correct = 0
    totalsize = 0
    loss_tot = 0.0
    num = 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            # predSoftmax = nn.Softmax(dim=1)(pred)
            loss = loss_fn(pred,y)
            correct += (pred.argmax(1) == y.argmax(1)).sum().item()
            totalsize += pred.shape[0]
            loss_tot += loss.item()
            num += 1
            X.cpu()
            y.cpu()
            
    print(f"Correct/Total: {correct}/{totalsize}")
    correct /= totalsize
    validation_accuracy.append(correct*100)
    print(f"Validation Loss:  {(loss_tot):>0.5f}")
    print(f"Validation Accuracy: {(100*correct):>0.5f}%\n")
    current_max_val_acc = max(current_max_val_acc,100*correct)
    print(f"Current Best Validation Accuracy: {(current_max_val_acc):>0.5f}%\n")
    return loss_tot

# %%
class XRayToothDataset(Dataset):
    def __init__(self, cwd, img_dir, transform=None, target_height=None, target_width=None):
        self.dataset_path = cwd + '/' + img_dir
        self.transform = transform
        self.target_height = target_height
        self.target_width = target_width

    def __len__(self):
        return len(os.listdir(self.dataset_path))

    def __getitem__(self, idx):
        if idx  >= len(os.listdir(self.dataset_path)):
            print("No datafile/image at index : "+ str(idx))
            return None
        img_filename = os.listdir(self.dataset_path)[idx]
        age = float(img_filename.split("_")[1][:-4])
        age_gt = get_ground_truth(age)
        image_tensor = read_image(path=self.dataset_path + '/' + img_filename)
        image_tensor = image_tensor.reshape(1, 3, image_tensor.shape[-2], image_tensor.shape[-1])
        if self.target_height and self.target_width: # Resize the image 
            image_tensor = torch.nn.functional.interpolate(image_tensor, (self.target_height,self.target_width))
        if self.transform: image_tensor = self.transform(image_tensor) # Apply transformations
        image_tensor = (image_tensor-image_tensor.min())/(image_tensor.max()-image_tensor.min())
        return image_tensor.reshape(-1,image_tensor.shape[-2],image_tensor.shape[-1]).to(torch.float32), torch.tensor(age_gt)

# %%
# Data Augmentation Transformations 
data_augmentation_transformations = T.RandomChoice([
    T.RandomAffine(degrees=0), # No Augmentation
    T.Lambda(lambda x: TF.hflip(img=x)) # Horizontal Flip

    # Geometric Transformations:
    # T.RandomAffine(degrees=0, scale=(1.3,1.3)), # Scale
    # T.RandomAffine(degrees=0, translate=(0.5,0.5)), # Translate
    # T.RandomAffine(degrees=(-8, 8)), # Rotate
    # T.Lambda(lambda x: TF.hflip(img=x)), # Reflect

    # Occlusion:
    # T.Compose([T.RandomErasing(p=1, scale=(0.0008, 0.0008), ratio=(1,1))]*100), # Occlusion

    # Intensity Operations
    # T.Lambda(lambda x: TF.adjust_gamma(img=x, gamma=0.5)), # Gamma Contrast
    # T.Lambda(lambda x: TF.adjust_contrast(x, contrast_factor=2.0)), # Linear Contrast

    # Filtering:
    # T.Lambda(lambda x: TF.adjust_sharpness(img=x, sharpness_factor=4)), #Sharpen
    # T.GaussianBlur(kernel_size=(15,15), sigma=(0.01, 1)), # Gaussian Blur
])

# %%
training_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/training', transform=data_augmentation_transformations, target_height=384, target_width=384)
validation_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/validation', transform=None, target_height=384, target_width=384)

# %%
# Testing augmentations (if we used any)
plt.imshow(training_data[0][0][0], cmap='gray')

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3),

            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3),

            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3),

            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3),
            
            nn.Conv2d(in_channels=256, out_channels=280, kernel_size=2),
            nn.ReLU(),

            nn.Flatten(),
        )

        self.fc = nn.Sequential(
            nn.Linear(2520,512),
            nn.ReLU(),
            nn.Linear(512,128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128,6),
            nn.Softmax(dim=1)
        )
    
    def forward(self, x):
        x = self.features(x)
        x = self.fc(x)
        return x

# %%
model = NeuralNetwork().to(device)

# %%
# Test a forward pass
with torch.no_grad():
    print(model(training_data[0][0].reshape(-1,3,384,384).to(device)))
# Out:
# tensor([[0.1510, 0.1637, 0.1712, 0.1716, 0.1719, 0.1706]], device='cuda:0')

# %%
# Training Hyperparameters
epochs = 100
batch_size = 50
learning_rate = 1e-2
momentum=0.9

# %%
training_data_loader = DataLoader(training_data, batch_size, shuffle = True)
validation_data_loader = DataLoader(validation_data, batch_size, shuffle = False)

# %%
class CustomNLLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, predicted, ground_truth):
        indices = torch.argmax(ground_truth, dim=1)
        selected_probs = torch.gather(predicted, 1, indices.view(-1, 1))
        loss = -torch.log(selected_probs).mean()
        return loss

# %%
loss_function=CustomNLLoss()
optimizer=torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=5, min_lr=1e-8,verbose=True)

# %%
# Training
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data_loader, model, loss_function, optimizer)
    val_loss = validation(validation_data_loader, model, loss_function)
    scheduler.step(val_loss)
    # torch.save(model, 'model.pth')
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# training loss: 25.79170
# Correct/Total: 67/129
# Validation Loss:  4.45610
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 2
# -------------------------------
# training loss: 9.74905
# Correct/Total: 67/129
# Validation Loss:  4.44709
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 3
# -------------------------------
# training loss: 8.76886
# Correct/Total: 67/129
# Validation Loss:  4.39932
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 4
# -------------------------------
# training loss: 8.87263
# Correct/Total: 67/129
# Validation Loss:  4.14895
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 5
# -------------------------------
# training loss: 8.45574
# Correct/Total: 67/129
# Validation Loss:  4.11885
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 6
# -------------------------------
# training loss: 8.33111
# Correct/Total: 67/129
# Validation Loss:  4.11738
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 7
# -------------------------------
# training loss: 8.41278
# Correct/Total: 67/129
# Validation Loss:  4.11407
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 8
# -------------------------------
# training loss: 8.20593
# Correct/Total: 67/129
# Validation Loss:  4.10460
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 9
# -------------------------------
# training loss: 8.26996
# Correct/Total: 67/129
# Validation Loss:  4.09702
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 10
# -------------------------------
# training loss: 8.25413
# Correct/Total: 67/129
# Validation Loss:  4.07748
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 11
# -------------------------------
# training loss: 8.19561
# Correct/Total: 67/129
# Validation Loss:  4.08024
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 12
# -------------------------------
# training loss: 8.25973
# Correct/Total: 67/129
# Validation Loss:  4.04687
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 13
# -------------------------------
# training loss: 8.08517
# Correct/Total: 67/129
# Validation Loss:  3.88966
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 14
# -------------------------------
# training loss: 7.98126
# Correct/Total: 67/129
# Validation Loss:  4.07580
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 15
# -------------------------------
# training loss: 8.00691
# Correct/Total: 67/129
# Validation Loss:  3.86230
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 16
# -------------------------------
# training loss: 7.74556
# Correct/Total: 67/129
# Validation Loss:  3.83647
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 17
# -------------------------------
# training loss: 7.63262
# Correct/Total: 67/129
# Validation Loss:  3.85903
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 18
# -------------------------------
# training loss: 7.69383
# Correct/Total: 67/129
# Validation Loss:  3.77635
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 19
# -------------------------------
# training loss: 7.70891
# Correct/Total: 67/129
# Validation Loss:  3.94403
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 20
# -------------------------------
# training loss: 7.85421
# Correct/Total: 67/129
# Validation Loss:  3.80781
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 21
# -------------------------------
# training loss: 7.63691
# Correct/Total: 67/129
# Validation Loss:  3.73594
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 22
# -------------------------------
# training loss: 7.50727
# Correct/Total: 67/129
# Validation Loss:  3.75105
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 23
# -------------------------------
# training loss: 7.58165
# Correct/Total: 67/129
# Validation Loss:  3.72335
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 24
# -------------------------------
# training loss: 7.46165
# Correct/Total: 67/129
# Validation Loss:  3.73326
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 25
# -------------------------------
# training loss: 7.37989
# Correct/Total: 67/129
# Validation Loss:  3.64070
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 26
# -------------------------------
# training loss: 7.37011
# Correct/Total: 66/129
# Validation Loss:  3.58324
# Validation Accuracy: 51.16279%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 27
# -------------------------------
# training loss: 7.03303
# Correct/Total: 69/129
# Validation Loss:  3.54068
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 53.48837%
#
# Epoch 28
# -------------------------------
# training loss: 6.95379
# Correct/Total: 68/129
# Validation Loss:  3.45023
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 53.48837%
#
# Epoch 29
# -------------------------------
# training loss: 7.09296
# Correct/Total: 68/129
# Validation Loss:  3.67511
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 53.48837%
#
# Epoch 30
# -------------------------------
# training loss: 7.08035
# Correct/Total: 75/129
# Validation Loss:  3.43463
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 31
# -------------------------------
# training loss: 6.90772
# Correct/Total: 73/129
# Validation Loss:  3.37966
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 32
# -------------------------------
# training loss: 6.82953
# Correct/Total: 69/129
# Validation Loss:  3.46060
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 33
# -------------------------------
# training loss: 6.96986
# Correct/Total: 75/129
# Validation Loss:  3.35941
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 34
# -------------------------------
# training loss: 7.27405
# Correct/Total: 65/129
# Validation Loss:  3.46781
# Validation Accuracy: 50.38760%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 35
# -------------------------------
# training loss: 8.29472
# Correct/Total: 69/129
# Validation Loss:  3.92992
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 36
# -------------------------------
# training loss: 7.59374
# Correct/Total: 67/129
# Validation Loss:  3.85607
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 37
# -------------------------------
# training loss: 7.38340
# Correct/Total: 67/129
# Validation Loss:  3.80106
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 38
# -------------------------------
# training loss: 7.33227
# Correct/Total: 67/129
# Validation Loss:  3.73016
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 39
# -------------------------------
# training loss: 7.02548
# Correct/Total: 67/129
# Validation Loss:  3.63996
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 00039: reducing learning rate of group 0 to 1.0000e-03.
# Epoch 40
# -------------------------------
# training loss: 6.86418
# Correct/Total: 67/129
# Validation Loss:  3.61050
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 41
# -------------------------------
# training loss: 6.92667
# Correct/Total: 68/129
# Validation Loss:  3.56450
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 42
# -------------------------------
# training loss: 6.74333
# Correct/Total: 68/129
# Validation Loss:  3.55673
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 43
# -------------------------------
# training loss: 6.84789
# Correct/Total: 68/129
# Validation Loss:  3.54548
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 44
# -------------------------------
# training loss: 6.88158
# Correct/Total: 69/129
# Validation Loss:  3.53618
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 45
# -------------------------------
# training loss: 6.75425
# Correct/Total: 70/129
# Validation Loss:  3.51920
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 00045: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 46
# -------------------------------
# training loss: 6.72996
# Correct/Total: 70/129
# Validation Loss:  3.51577
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 47
# -------------------------------
# training loss: 6.71764
# Correct/Total: 70/129
# Validation Loss:  3.51317
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 48
# -------------------------------
# training loss: 6.68881
# Correct/Total: 70/129
# Validation Loss:  3.51057
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 49
# -------------------------------
# training loss: 6.66082
# Correct/Total: 70/129
# Validation Loss:  3.50846
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 50
# -------------------------------
# training loss: 6.66221
# Correct/Total: 70/129
# Validation Loss:  3.50712
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 51
# -------------------------------
# training loss: 6.70665
# Correct/Total: 70/129
# Validation Loss:  3.50580
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 00051: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 52
# -------------------------------
# training loss: 6.71396
# Correct/Total: 70/129
# Validation Loss:  3.50567
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 53
# -------------------------------
# training loss: 6.73155
# Correct/Total: 70/129
# Validation Loss:  3.50553
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 54
# -------------------------------
# training loss: 6.70469
# Correct/Total: 70/129
# Validation Loss:  3.50544
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 55
# -------------------------------
# training loss: 6.60491
# Correct/Total: 70/129
# Validation Loss:  3.50533
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 56
# -------------------------------
# training loss: 6.62529
# Correct/Total: 70/129
# Validation Loss:  3.50521
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 57
# -------------------------------
# training loss: 6.86787
# Correct/Total: 70/129
# Validation Loss:  3.50504
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 00057: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 58
# -------------------------------
# training loss: 6.71550
# Correct/Total: 70/129
# Validation Loss:  3.50503
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 59
# -------------------------------
# training loss: 6.66962
# Correct/Total: 70/129
# Validation Loss:  3.50502
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 60
# -------------------------------
# training loss: 6.59878
# Correct/Total: 70/129
# Validation Loss:  3.50501
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 61
# -------------------------------
# training loss: 6.61657
# Correct/Total: 70/129
# Validation Loss:  3.50500
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 62
# -------------------------------
# training loss: 6.68574
# Correct/Total: 70/129
# Validation Loss:  3.50500
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 63
# -------------------------------
# training loss: 6.76960
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 00063: reducing learning rate of group 0 to 1.0000e-07.
# Epoch 64
# -------------------------------
# training loss: 6.74576
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 65
# -------------------------------
# training loss: 6.66407
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 66
# -------------------------------
# training loss: 6.64641
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 67
# -------------------------------
# training loss: 6.50778
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 68
# -------------------------------
# training loss: 6.72262
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 69
# -------------------------------
# training loss: 6.71799
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 00069: reducing learning rate of group 0 to 1.0000e-08.
# Epoch 70
# -------------------------------
# training loss: 6.79395
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 71
# -------------------------------
# training loss: 6.73033
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 72
# -------------------------------
# training loss: 6.59236
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 73
# -------------------------------
# training loss: 6.70228
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 74
# -------------------------------
# training loss: 6.65091
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 75
# -------------------------------
# training loss: 6.58909
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 76
# -------------------------------
# training loss: 6.66988
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 77
# -------------------------------
# training loss: 6.80438
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 78
# -------------------------------
# training loss: 6.66170
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 79
# -------------------------------
# training loss: 6.52972
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 80
# -------------------------------
# training loss: 6.66519
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 81
# -------------------------------
# training loss: 6.60581
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 82
# -------------------------------
# training loss: 6.64642
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 83
# -------------------------------
# training loss: 6.72836
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 84
# -------------------------------
# training loss: 6.60649
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 85
# -------------------------------
# training loss: 6.70537
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 86
# -------------------------------
# training loss: 6.71859
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 87
# -------------------------------
# training loss: 6.55538
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 88
# -------------------------------
# training loss: 6.65672
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 89
# -------------------------------
# training loss: 6.61413
# Correct/Total: 70/129
# Validation Loss:  3.50498
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 90
# -------------------------------
# training loss: 6.61764
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 91
# -------------------------------
# training loss: 6.78258
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 92
# -------------------------------
# training loss: 6.48139
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 93
# -------------------------------
# training loss: 6.72692
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 94
# -------------------------------
# training loss: 6.57750
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 95
# -------------------------------
# training loss: 6.67274
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 96
# -------------------------------
# training loss: 6.77800
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 97
# -------------------------------
# training loss: 6.58429
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 98
# -------------------------------
# training loss: 6.68251
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 99
# -------------------------------
# training loss: 6.73078
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 100
# -------------------------------
# training loss: 6.63982
# Correct/Total: 70/129
# Validation Loss:  3.50497
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 58.13953%
#
# Done!

# %%
plt.ylim(50,60)
plt.plot(validation_accuracy)
plt.show()
