# %%
# !pip install pytorch-metric-learning
# !pip install torch-summary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytorch-metric-learning in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->pytorch-metric-learning) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->pytorch-metric-learning) (16.0.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->pytorch-metric-learning) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->pytorch-metric-learning) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-summary in /usr/local/lib/python3.10/dist-packages (1.4.5)

# %%
import os
import json
import zipfile
import subprocess
import shutil
import getpass
import math
import numpy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image,ImageReadMode
import matplotlib.pyplot as plt
from pytorch_metric_learning import losses, regularizers
from torchsummary import summary

# %%
torch.manual_seed(20)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
# device = "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
dataset_save_dir = './dataset'

# %%
def one_hot_encode(val):
    arr = numpy.zeros((6,), dtype=int)
    arr[val] = 1
    return arr

def get_bucket_id(age):
  age_floor = int(age)
  if age_floor >= 0 and age_floor <= 5: return 0
  elif age_floor >= 6 and age_floor <= 12: return 1
  elif age_floor >= 13 and age_floor <= 19: return 2
  elif age_floor >= 20 and age_floor <= 29: return 3
  elif age_floor >= 30 and age_floor <= 59: return 4
  else: return 5

def get_ground_truth(age):
  return one_hot_encode(get_bucket_id(age))

# %%
def get_random_two_different_int(low=0, high=6, size=1):
  num1 = torch.randint(low,high, (size,)).item()
  num2 = torch.randint(low,high, (size,)).item()
  while num1 == num2: num2 = torch.randint(low,high, (size,)).item()
  return num1,num2

# %%
def train(dataloader, model, loss_fn, optimizer):
    torch.cuda.empty_cache()
    size = len(dataloader.dataset)
    model.train()
    loss_tot = 0.0
    num = 0
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        embeddings = model.forward_once(X)
        pairwise_distances = torch.cdist(embeddings,embeddings)

        # Find triplets
        triplets = []
        embedding_anchor = []
        embedding_pos = []
        embedding_neg = []
        batch_size = embeddings.size(0)
        embedding_dim = embeddings.size(1)

        for i in range(batch_size):
            label_i = y[i]
            positive_indices = torch.where(y == label_i)[0]
            negative_indices = torch.where(y != label_i)[0]
            farthest_pos_index = positive_indices[torch.argmax(pairwise_distances[i][positive_indices])]
            nearest_neg_index = negative_indices[torch.argmin(pairwise_distances[i][negative_indices])]
            embedding_anchor.append(embeddings[i])
            embedding_pos.append(embeddings[farthest_pos_index])
            embedding_neg.append(embeddings[nearest_neg_index])

        embedding_anchor = torch.stack(embedding_anchor, dim=0)
        embedding_pos = torch.stack(embedding_pos, dim=0)
        embedding_neg = torch.stack(embedding_neg, dim=0)

        # Forward
        optimizer.zero_grad()
        ea, ep, en = model.forward_only_fc(embedding_anchor, embedding_pos, embedding_neg)
    
        loss = loss_fn(ea, ep, en)
        loss.backward()
        optimizer.step()

        loss_tot += loss.item()
        num += 1

        X.cpu()
        y.cpu()

        # Gather data and report
        if batch % 4 == 0:
            current = (batch + 1) * len(X)
            print(f"loss: {loss.item():>7f}  [{current:>5d}/{size:>5d}]")

    # loss_tot /= num
    print(f'training loss: {(loss_tot):>0.5f}')

# %%
validation_accuracy = []
current_max_val_acc = 0.0
def validation(dataloader, model, loss_fn):
    global current_max_val_acc
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    correct = 0
    totalsize = 0
    loss_tot = 0.0
    num = 0
    with torch.no_grad():
        for batch, (X, y) in enumerate(dataloader):
            X, y = X.to(device), y.to(device)

            embeddings = model.forward_once(X)
            pairwise_distances = torch.cdist(embeddings,embeddings)

            # Find triplets
            triplets = []
            embedding_anchor = []
            embedding_pos = []
            embedding_neg = []
            batch_size = embeddings.size(0)
            embedding_dim = embeddings.size(1)

            for i in range(batch_size):
                label_i = y[i]
                positive_indices = torch.where(y == label_i)[0]
                negative_indices = torch.where(y != label_i)[0]
                farthest_pos_index = positive_indices[torch.argmax(pairwise_distances[i][positive_indices])]
                nearest_neg_index = negative_indices[torch.argmin(pairwise_distances[i][negative_indices])]
                embedding_anchor.append(embeddings[i])
                embedding_pos.append(embeddings[farthest_pos_index])
                embedding_neg.append(embeddings[nearest_neg_index])

            embedding_anchor = torch.stack(embedding_anchor, dim=0)
            embedding_pos = torch.stack(embedding_pos, dim=0)
            embedding_neg = torch.stack(embedding_neg, dim=0)

            # Forward
            ea, ep, en = model.forward_only_fc(embedding_anchor, embedding_pos, embedding_neg)
            
            distances = torch.nn.functional.pairwise_distance(ea, en) - torch.nn.functional.pairwise_distance(ea, ep)
            predictions = (distances >= 0).float()

            correct += torch.sum(predictions).item()
            totalsize += ea.shape[0]

            loss = loss_fn(ea, ep, en)

            loss_tot += loss.item()

            X.cpu()
            y.cpu()
            
    print(f"Correct/Total: {correct}/{totalsize}")
    correct /= totalsize
    validation_accuracy.append(correct*100)
    print(f"Validation Loss:  {(loss_tot):>0.5f}")
    print(f"Validation Accuracy: {(100*correct):>0.5f}%\n")
    current_max_val_acc = max(current_max_val_acc,100*correct)
    print(f"Current Best Validation Accuracy: {(current_max_val_acc):>0.5f}%\n")
    return loss_tot

# %%
data_augmentation_transformations = T.RandomChoice([ # Geometric Transformation
    T.RandomAffine(degrees=0),
    T.Lambda(lambda x: TF.hflip(img=x))
    # T.RandomAffine(degrees=0), # No Transformation
    # Geometric Transformations:
    # T.RandomAffine(degrees=0, scale=(1.3,1.3)), # Scale
    # T.RandomAffine(degrees=0, translate=(0.5,0.5)), # Translate
    # T.RandomAffine(degrees=(-8, 8)), # Rotate
    # T.Lambda(lambda x: TF.hflip(img=x)), # Reflect
    # Skipping Shearing & Skewing as they don't make sense in this context of Teeth X-Ray
    # Occlusion:
    # T.Compose([T.RandomErasing(p=1, scale=(0.0008, 0.0008), ratio=(1,1))]*100), # Occlusion
    # T.Compose([T.RandomErasing(p=1, scale=(0.0008, 0.0008), ratio=(1,1))]*100), # Occlusion
    # T.Compose([T.RandomErasing(p=1, scale=(0.0008, 0.0008), ratio=(1,1))]*100), # Occlusion
    # Intensity Operations
    # T.Lambda(lambda x: TF.adjust_gamma(img=x, gamma=0.5)), # Gamma Contrast
    # T.Lambda(lambda x: TF.adjust_contrast(x, contrast_factor=2.0)), # Linear Contrast
    # Histogram Equalizer skipped as we need to typecast it to uint8 for that
    # Skipping Noise injection as we want to easily normalize it later 
    # Filtering:
    # T.Lambda(lambda x: TF.adjust_sharpness(img=x, sharpness_factor=4)), #Sharpen
    # T.GaussianBlur(kernel_size=(15,15), sigma=(0.01, 1)), # Gaussian Blur
])

# %%
class XRayToothDataset(Dataset):
    def __init__(self, cwd, img_dir, transform=None, target_height=None, target_width=None):
        self.dataset_path = cwd + '/' + img_dir
        self.transform = transform
        self.target_height = target_height
        self.target_width = target_width

    def __len__(self):
        return len(os.listdir(self.dataset_path))

    def __getitem__(self, idx):
        if idx  >= len(os.listdir(self.dataset_path)):
            print("No datafile/image at index : "+ str(idx))
            return None
        img_filename = os.listdir(self.dataset_path)[idx]
        age = float(img_filename.split("_")[1][:-4])
        age_gt = get_bucket_id(age)
        image_tensor = read_image(path=self.dataset_path + '/' + img_filename)
        image_tensor = image_tensor.reshape(1, 3, image_tensor.shape[-2], image_tensor.shape[-1])
        if self.target_height and self.target_width: # Resize the image 
            image_tensor = torch.nn.functional.interpolate(image_tensor, (self.target_height,self.target_width))
        if self.transform: image_tensor = self.transform(image_tensor) # Apply transformations
        image_tensor = (image_tensor-image_tensor.min())/(image_tensor.max()-image_tensor.min())
        return image_tensor.reshape(-1,image_tensor.shape[-2],image_tensor.shape[-1]).to(torch.float32), torch.tensor(age_gt)

# %%
training_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/training', transform=data_augmentation_transformations, target_height=224, target_width=224)
validation_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/validation', transform=None, target_height=224, target_width=224)

# %%
from torchvision.models import vit_l_32, ViT_L_32_Weights

pretrained_vit = vit_l_32(weights=ViT_L_32_Weights.IMAGENET1K_V1)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = pretrained_vit

        for param in self.backbone.parameters():
            param.requires_grad = False

        self.fc = nn.Sequential(
            nn.Dropout(0.6),
            nn.Linear(1000,512),
            nn.Dropout(0.7),
            nn.Linear(512,6)
        )

    def forward_once(self, x):
        x = self.backbone(x)
        return x
    
    def forward_only_fc(self, ea, ep, en):
        ea = self.fc(ea)
        ep = self.fc(ep)
        en = self.fc(en)
        
        return ea, ep, en
    
    def forward(self, xA, xP, xN):
        ea = self.fc(self.forward_once(xA))
        ep = self.fc(self.forward_once(xP))
        en = self.fc(self.forward_once(xN))
        
        return ea, ep, en

# %%
model = NeuralNetwork().to(device)

# %%
# Training Hyperparameters
epochs = 600
batch_size = 50
learning_rate = 1e-2
momentum=0.9
weight_decay=0.05

# %%
training_data_loader = DataLoader(training_data, batch_size, shuffle = True)
validation_data_loader = DataLoader(validation_data, batch_size, shuffle = False)

# %%
loss_function=nn.TripletMarginLoss(margin=5.0)
optimizer=torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=5, min_lr=1e-4,verbose=True)

# %%
# Training
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data_loader, model, loss_function, optimizer)
    val_loss = validation(validation_data_loader, model, loss_function)
    scheduler.step(val_loss)
    # torch.save(model, 'model.pth')
print("Done!")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 149
# -------------------------------
# loss: 4.818784  [   50/  296]
# loss: 4.944316  [  250/  296]
# training loss: 25.18595
# Correct/Total: 26.0/129
# Validation Loss:  17.10046
# Validation Accuracy: 20.15504%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 150
# -------------------------------
# loss: 5.155196  [   50/  296]
# loss: 5.029342  [  250/  296]
# training loss: 27.26602
# Correct/Total: 30.0/129
# Validation Loss:  17.07662
# Validation Accuracy: 23.25581%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 00150: reducing learning rate of group 0 to 1.0942e-03.
# Epoch 151
# -------------------------------
# loss: 2.581809  [   50/  296]
# loss: 3.566315  [  250/  296]
# training loss: 24.41674
# Correct/Total: 35.0/129
# Validation Loss:  16.82063
# Validation Accuracy: 27.13178%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 152
# -------------------------------
# loss: 5.687599  [   50/  296]
# loss: 5.007554  [  250/  296]
# training loss: 27.67696
# Correct/Total: 38.0/129
# Validation Loss:  16.48681
# Validation Accuracy: 29.45736%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 153
# -------------------------------
# loss: 4.106646  [   50/  296]
# loss: 3.113954  [  250/  296]
# training loss: 23.36811
# Correct/Total: 41.0/129
# Validation Loss:  16.32604
# Validation Accuracy: 31.78295%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 154
# -------------------------------
# loss: 4.310722  [   50/  296]
# loss: 4.510717  [  250/  296]
# training loss: 27.72082
# Correct/Total: 39.0/129
# Validation Loss:  16.34929
# Validation Accuracy: 30.23256%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 155
# -------------------------------
# loss: 4.758083  [   50/  296]
# loss: 4.124522  [  250/  296]
# training loss: 24.14387
# Correct/Total: 30.0/129
# Validation Loss:  16.57596
# Validation Accuracy: 23.25581%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 156
# -------------------------------
# loss: 4.590343  [   50/  296]
# loss: 4.431534  [  250/  296]
# training loss: 26.35558
# Correct/Total: 24.0/129
# Validation Loss:  16.72795
# Validation Accuracy: 18.60465%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 157
# -------------------------------
# loss: 3.802545  [   50/  296]
# loss: 5.724225  [  250/  296]
# training loss: 26.31615
# Correct/Total: 30.0/129
# Validation Loss:  16.62551
# Validation Accuracy: 23.25581%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 158
# -------------------------------
# loss: 4.447676  [   50/  296]
# loss: 3.697648  [  250/  296]
# training loss: 24.05938
# Correct/Total: 32.0/129
# Validation Loss:  16.28255
# Validation Accuracy: 24.80620%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 159
# -------------------------------
# loss: 4.766366  [   50/  296]
# loss: 3.288910  [  250/  296]
# training loss: 24.74011
# Correct/Total: 38.0/129
# Validation Loss:  15.99552
# Validation Accuracy: 29.45736%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 160
# -------------------------------
# loss: 3.904707  [   50/  296]
# loss: 3.597933  [  250/  296]
# training loss: 23.72875
# Correct/Total: 42.0/129
# Validation Loss:  15.90278
# Validation Accuracy: 32.55814%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch
# Validation Accuracy: 28.68217%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 194
# -------------------------------
# loss: 2.572294  [   50/  296]
# loss: 3.814919  [  250/  296]
# training loss: 21.51716
# Correct/Total: 39.0/129
# Validation Loss:  16.20488
# Validation Accuracy: 30.23256%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 195
# -------------------------------
# loss: 3.765554  [   50/  296]
# loss: 4.418839  [  250/  296]
# training loss: 24.44776
# Correct/Total: 38.0/129
# Validation Loss:  15.97591
# Validation Accuracy: 29.45736%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 196
# -------------------------------
# loss: 4.837447  [   50/  296]
# loss: 2.978980  [  250/  296]
# training loss: 21.70772
# Correct/Total: 39.0/129
# Validation Loss:  15.84475
# Validation Accuracy: 30.23256%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 197
# -------------------------------
# loss: 3.937765  [   50/  296]
# loss: 3.701997  [  250/  296]
# training loss: 23.17042
# Correct/Total: 40.0/129
# Validation Loss:  15.85776
# Validation Accuracy: 31.00775%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 198
# -------------------------------
# loss: 4.065150  [   50/  296]
# loss: 3.891611  [  250/  296]
# training loss: 21.11112
# Correct/Total: 38.0/129
# Validation Loss:  15.89606
# Validation Accuracy: 29.45736%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 199
# -------------------------------
# loss: 3.494396  [   50/  296]
# loss: 4.141452  [  250/  296]
# training loss: 22.57523
# Correct/Total: 39.0/129
# Validation Loss:  15.89888
# Validation Accuracy: 30.23256%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 200
# -------------------------------
# loss: 4.019805  [   50/  296]
# loss: 2.884777  [  250/  296]
# training loss: 21.54896
# Correct/Total: 37.0/129
# Validation Loss:  15.90722
# Validation Accuracy: 28.68217%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 201
# -------------------------------
# loss: 4.161830  [   50/  296]
# loss: 4.063094  [  250/  296]
# training loss: 23.17128
# Correct/Total: 35.0/129
# Validation Loss:  16.04305
# Validation Accuracy: 27.13178%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 202
# -------------------------------
# loss: 3.446784  [   50/  296]
# loss: 4.281422  [  250/  296]
# training loss: 23.73130
# Correct/Total: 37.0/129
# Validation Loss:  16.08515
# Validation Accuracy: 28.68217%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 00202: reducing learning rate of group 0 to 5.8150e-04.
# Epoch 203
# -------------------------------
# loss: 4.012621  [   50/  296]
# loss: 2.991190  [  250/  296]
# training loss: 22.24031
# Correct/Total: 36.0/129
# Validation Loss:  16.01285
# Validation Accuracy: 27.90698%
#
# Current Best Validation Accuracy: 32.55814%
#
# Epoch 204
# -------------------------------
# loss: 3.591677  [   50/  296]
# loss: 3.809927  [  250/  296]
# training loss: 20.28839
# Correct/Total: 43.0/129
# Validation Loss:  15.94294
# Validation Accuracy: 33.33333%
#
# Current Best Validation Accuracy: 33.33333%
#
# Epoch 205
# -------------------------------
# loss: 3.047230  [   50/  296]
# loss: 4.355981  [  250/  296]
# training loss: 21.41670
# Correct/Total: 42.0/129
# Validation Loss:  15.93324
# Validation Accuracy: 32.55814%
#
# Current Best Validation Accuracy: 33.33333%
#
# Epoch 206
# -------------------------------
# loss: 3.486459  [   50/  296]
# loss: 4.151560  [  250/  296]
# training loss: 20.72235
# Correct/Total: 40.0/129
# Validation Loss:  15.87235
# Validation Accuracy: 31.00775%
#
# Current Best Validation Accuracy: 33.33333%
#
# Epoch 207
# -------------------------------
# loss: 4.322647  [   50/  296]
# loss: 3.545417  [  250/  296]
# training loss: 24.61230
# Correct/Total: 44.0/129
# Validation Loss:  15.80205
# Validation Accuracy: 34.10853%
#
# Current Best Validation Accuracy: 34.10853%
#
# Epoch 208
# -------------------------------
# loss: 4.177901  [   50/  296]
# loss: 3.424803  [  250/  296]
# training loss: 22.89445
# Correct/Total: 45.0/129
# Validation Loss:  15.69767
# Validation Accuracy: 34.88372%
#
# Current Best Validation Accuracy: 34.88372%
#
# Epoch 209
# -------------------------------
# loss: 3.459685  [   50/  296]
# loss: 3.548604  [  250/  296]
# training loss: 21.23628
# Correct/Total: 43.0/129
# Validation Loss:  15.67997
# Validation Accuracy: 33.33333%
#
# Current Best Validation Accuracy: 34.88372%
#
# Epoch 210
# -------------------------------
# loss: 3.399680  [   50/  296]
# loss: 4.366920  [  250/  296]
# training loss: 21.94248
# Correct/Total: 46.0/129
# Validation Loss:  15.70728
# Validation Accuracy: 35.65891%
#
# Current Best Validation Accuracy: 35.65891%
#
# Epoch

#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 311
# -------------------------------
# loss: 3.619208  [   50/  296]
# loss: 3.454214  [  250/  296]
# training loss: 20.76156
# Correct/Total: 36.0/129
# Validation Loss:  15.65898
# Validation Accuracy: 27.90698%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 312
# -------------------------------
# loss: 3.062252  [   50/  296]
# loss: 3.128336  [  250/  296]
# training loss: 17.96853
# Correct/Total: 38.0/129
# Validation Loss:  15.65720
# Validation Accuracy: 29.45736%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 313
# -------------------------------
# loss: 2.848048  [   50/  296]
# loss: 3.831576  [  250/  296]
# training loss: 18.95279
# Correct/Total: 39.0/129
# Validation Loss:  15.66677
# Validation Accuracy: 30.23256%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 314
# -------------------------------
# loss: 3.362665  [   50/  296]
# loss: 3.033198  [  250/  296]
# training loss: 18.73676
# Correct/Total: 38.0/129
# Validation Loss:  15.66232
# Validation Accuracy: 29.45736%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 00314: reducing learning rate of group 0 to 1.0775e-04.
# Epoch 315
# -------------------------------
# loss: 2.881138  [   50/  296]
# loss: 3.654983  [  250/  296]
# training loss: 20.40700
# Correct/Total: 41.0/129
# Validation Loss:  15.63978
# Validation Accuracy: 31.78295%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 316
# -------------------------------
# loss: 2.603380  [   50/  296]
# loss: 3.223239  [  250/  296]
# training loss: 17.95908
# Correct/Total: 42.0/129
# Validation Loss:  15.62139
# Validation Accuracy: 32.55814%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 317
# -------------------------------
# loss: 3.158990  [   50/  296]
# loss: 2.785989  [  250/  296]
# training loss: 19.59479
# Correct/Total: 43.0/129
# Validation Loss:  15.62230
# Validation Accuracy: 33.33333%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 318
# -------------------------------
# loss: 2.483978  [   50/  296]
# loss: 5.229595  [  250/  296]
# training loss: 21.35644
# Correct/Total: 44.0/129
# Validation Loss:  15.61579
# Validation Accuracy: 34.10853%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 319
# -------------------------------
# loss: 3.789749  [   50/  296]
# loss: 3.844051  [  250/  296]
# training loss: 21.03617
# Correct/Total: 44.0/129
# Validation Loss:  15.62021
# Validation Accuracy: 34.10853%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 320
# -------------------------------
# loss: 2.445181  [   50/  296]
# loss: 2.836098  [  250/  296]
# training loss: 18.88541
# Correct/Total: 45.0/129
# Validation Loss:  15.64555
# Validation Accuracy: 34.88372%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 00320: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 321
# -------------------------------
# loss: 4.355539  [   50/  296]
# loss: 3.014050  [  250/  296]
# training loss: 22.56228
# Correct/Total: 41.0/129
# Validation Loss:  15.66527
# Validation Accuracy: 31.78295%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 322
# -------------------------------
# loss: 2.796054  [   50/  296]
# loss: 3.341028  [  250/  296]
# training loss: 21.05546
# Correct/Total: 42.0/129
# Validation Loss:  15.65858
# Validation Accuracy: 32.55814%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 323
# -------------------------------
# loss: 3.319820  [   50/  296]
# loss: 3.973957  [  250/  296]
# training loss: 20.77739
# Correct/Total: 40.0/129
# Validation Loss:  15.64702
# Validation Accuracy: 31.00775%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 324
# -------------------------------
# loss: 3.943870  [   50/  296]
# loss: 2.585275  [  250/  296]
# training loss: 19.84281
# Correct/Total: 41.0/129
# Validation Loss:  15.63790
# Validation Accuracy: 31.78295%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 325
# -------------------------------
# loss: 2.976764  [   50/  296]
# loss: 3.340539  [  250/  296]
# training loss: 18.95639
# Correct/Total: 41.0/129
# Validation Loss:  15.62253
# Validation Accuracy: 31.78295%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 326
# -------------------------------
# loss: 2.916883  [   50/  296]
# loss: 3.661371  [  250/  296]
# training loss: 20.53941
# Correct/Total: 42.0/129
# Validation Loss:  15.59747
# Validation Accuracy: 32.55814%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 327
# -------------------------------
# loss: 3.808472  [   50/  296]
# loss: 3.718450  [  250/  296]
# training loss: 20.12006
# Correct/Total: 44.0/129
# Validation Loss:  15.56235
# Validation Accuracy: 34.10853%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 328
# -------------------------------
# loss: 2.471585  [   50/  296]
# loss: 2.888777  [  250/  296]
# training loss: 18.69992
# Correct/Total: 44.0/129
# Validation Loss:  15.56595
# Validation Accuracy: 34.10853%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 329
# -------------------------------
# loss: 3.622279  [   50/  296]
# loss: 2.896124  [  250/  296]
# training loss: 20.04865
# Correct/Total: 44.0/129
# Validation Loss:  15.57261
# Validation Accuracy: 34.10853%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 330
# -------------------------------
# loss: 3.449245  [   50/  296]
# loss: 4.209641  [  250/  296]
# training loss: 22.14438
# Correct/Total: 40.0/129
# Validation Loss:  15.57453
# Validation Accuracy: 31.00775%
#
# Current Best Validation Accuracy: 38.75969%
#
# Epoch 331
# -------------------------------
# loss: 3.196663  [   50/  296]
# loss: 3.572245  [  250/  296]
# training loss: 18.56062
# Correct/Total: 39.0/129
# Validation Loss:  15.58696
# ...
# -------------------------------
# loss: 2.802331  [   50/  296]
# loss: 3.499175  [  250/  296]
# training loss: 18.23868
# Correct/Total: 43.0/129
# Validation Loss:  15.30888
# Validation Accuracy: 33.33333%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 539
# -------------------------------
# loss: 4.264980  [   50/  296]
# loss: 2.542876  [  250/  296]
# training loss: 19.85321
# Correct/Total: 44.0/129
# Validation Loss:  15.30407
# Validation Accuracy: 34.10853%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 540
# -------------------------------
# loss: 4.029529  [   50/  296]
# loss: 3.262519  [  250/  296]
# training loss: 21.34096
# Correct/Total: 47.0/129
# Validation Loss:  15.28311
# Validation Accuracy: 36.43411%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 541
# -------------------------------
# loss: 3.211017  [   50/  296]
# loss: 2.667473  [  250/  296]
# training loss: 17.55968
# Correct/Total: 48.0/129
# Validation Loss:  15.26481
# Validation Accuracy: 37.20930%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 542
# -------------------------------
# loss: 3.211324  [   50/  296]
# loss: 2.941404  [  250/  296]
# training loss: 17.79281
# Correct/Total: 52.0/129
# Validation Loss:  15.26254
# Validation Accuracy: 40.31008%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 543
# -------------------------------
# loss: 3.149065  [   50/  296]
# loss: 2.868652  [  250/  296]
# training loss: 18.63957
# Correct/Total: 52.0/129
# Validation Loss:  15.25460
# Validation Accuracy: 40.31008%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 544
# -------------------------------
# loss: 3.253949  [   50/  296]
# loss: 3.074433  [  250/  296]
# training loss: 17.85853
# Correct/Total: 53.0/129
# Validation Loss:  15.25785
# Validation Accuracy: 41.08527%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 545
# -------------------------------
# loss: 4.206512  [   50/  296]
# loss: 3.095596  [  250/  296]
# training loss: 20.35045
# Correct/Total: 55.0/129
# Validation Loss:  15.27063
# Validation Accuracy: 42.63566%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 546
# -------------------------------
# loss: 2.919214  [   50/  296]
# loss: 2.170211  [  250/  296]
# training loss: 17.73367
# Correct/Total: 55.0/129
# Validation Loss:  15.27477
# Validation Accuracy: 42.63566%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 547
# -------------------------------
# loss: 3.996002  [   50/  296]
# loss: 3.560328  [  250/  296]
# training loss: 21.37084
# Correct/Total: 57.0/129
# Validation Loss:  15.27329
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 548
# -------------------------------
# loss: 2.574980  [   50/  296]
# loss: 4.140859  [  250/  296]
# training loss: 19.50410
# Correct/Total: 57.0/129
# Validation Loss:  15.27420
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 549
# -------------------------------
# loss: 2.560065  [   50/  296]
# loss: 2.644523  [  250/  296]
# training loss: 19.54584
# Correct/Total: 54.0/129
# Validation Loss:  15.27447
# Validation Accuracy: 41.86047%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 550
# -------------------------------
# loss: 2.933959  [   50/  296]
# loss: 3.023317  [  250/  296]
# training loss: 17.67987
# Correct/Total: 53.0/129
# Validation Loss:  15.30588
# Validation Accuracy: 41.08527%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 551
# -------------------------------
# loss: 3.172374  [   50/  296]
# loss: 3.269997  [  250/  296]
# training loss: 19.41952
# Correct/Total: 45.0/129
# Validation Loss:  15.34480
# Validation Accuracy: 34.88372%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 552
# -------------------------------
# loss: 3.756456  [   50/  296]
# loss: 2.241612  [  250/  296]
# training loss: 19.99497
# Correct/Total: 46.0/129
# Validation Loss:  15.36252
# Validation Accuracy: 35.65891%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 553
# -------------------------------
# loss: 3.931954  [   50/  296]
# loss: 2.721828  [  250/  296]
# training loss: 20.01741
# Correct/Total: 46.0/129
# Validation Loss:  15.36516
# Validation Accuracy: 35.65891%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 554
# -------------------------------
# loss: 3.181658  [   50/  296]
# loss: 3.608154  [  250/  296]
# training loss: 21.09670
# Correct/Total: 50.0/129
# Validation Loss:  15.33092
# Validation Accuracy: 38.75969%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 555
# -------------------------------
# loss: 2.791587  [   50/  296]
# loss: 3.521138  [  250/  296]
# training loss: 20.85495
# Correct/Total: 51.0/129
# Validation Loss:  15.30094
# Validation Accuracy: 39.53488%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 556
# -------------------------------
# loss: 4.375444  [   50/  296]
# loss: 3.197379  [  250/  296]
# training loss: 20.41804
# Correct/Total: 53.0/129
# Validation Loss:  15.28904
# Validation Accuracy: 41.08527%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 557
# -------------------------------
# loss: 3.409697  [   50/  296]
# loss: 2.736255  [  250/  296]
# training loss: 17.70810
# Correct/Total: 53.0/129
# Validation Loss:  15.27410
# Validation Accuracy: 41.08527%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 558
# -------------------------------
# loss: 3.419597  [   50/  296]
# loss: 2.976197  [  250/  296]
# training loss: 19.95276
# Correct/Total: 51.0/129
# Validation Loss:  15.24530
# Validation Accuracy: 39.53488%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 559
# -------------------------------
# loss: 4.358110  [   50/  296]
# loss: 3.217631  [  250/  296]
# training loss: 20.21776
# Correct/Total: 51.0/129
# Validation Loss:  15.23365
# Validation Accuracy: 39.53488%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 560
# -------------------------------
# loss: 3.004450  [   50/  296]
# loss: 2.323483  [  250/  296]
# training loss: 19.07787
# Correct/Total: 51.0/129
# Validation Loss:  15.24378
# Validation Accuracy: 39.53488%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 561
# -------------------------------
# loss: 3.092371  [   50/  296]
# loss: 3.405029  [  250/  296]
# training loss: 20.53739
# Correct/Total: 47.0/129
# Validation Loss:  15.24435
# Validation Accuracy: 36.43411%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 562
# -------------------------------
# loss: 3.190900  [   50/  296]
# loss: 3.159822  [  250/  296]
# training loss: 19.43573
# Correct/Total: 51.0/129
# Validation Loss:  15.22044
# Validation Accuracy: 39.53488%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 563
# -------------------------------
# loss: 4.277923  [   50/  296]
# loss: 3.706346  [  250/  296]
# training loss: 17.15617
# Correct/Total: 50.0/129
# Validation Loss:  15.20473
# Validation Accuracy: 38.75969%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 564
# -------------------------------
# loss: 3.591960  [   50/  296]
# loss: 3.800447  [  250/  296]
# training loss: 20.45103
# Correct/Total: 49.0/129
# Validation Loss:  15.20695
# Validation Accuracy: 37.98450%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 565
# -------------------------------
# loss: 4.213983  [   50/  296]
# loss: 4.241649  [  250/  296]
# training loss: 21.70750
# Correct/Total: 49.0/129
# Validation Loss:  15.22114
# Validation Accuracy: 37.98450%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 566
# -------------------------------
# loss: 2.836230  [   50/  296]
# loss: 3.434331  [  250/  296]
# training loss: 21.06191
# Correct/Total: 50.0/129
# Validation Loss:  15.23646
# Validation Accuracy: 38.75969%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 567
# -------------------------------
# loss: 2.691005  [   50/  296]
# loss: 3.510919  [  250/  296]
# training loss: 19.15179
# Correct/Total: 53.0/129
# Validation Loss:  15.25625
# Validation Accuracy: 41.08527%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch
# Validation Accuracy: 41.08527%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 585
# -------------------------------
# loss: 3.348799  [   50/  296]
# loss: 2.871821  [  250/  296]
# training loss: 19.28097
# Correct/Total: 48.0/129
# Validation Loss:  15.28683
# Validation Accuracy: 37.20930%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 586
# -------------------------------
# loss: 3.834686  [   50/  296]
# loss: 3.632375  [  250/  296]
# training loss: 18.96700
# Correct/Total: 49.0/129
# Validation Loss:  15.27663
# Validation Accuracy: 37.98450%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 587
# -------------------------------
# loss: 2.795235  [   50/  296]
# loss: 3.995569  [  250/  296]
# training loss: 20.58171
# Correct/Total: 49.0/129
# Validation Loss:  15.26767
# Validation Accuracy: 37.98450%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 588
# -------------------------------
# loss: 2.955149  [   50/  296]
# loss: 2.953642  [  250/  296]
# training loss: 18.90767
# Correct/Total: 52.0/129
# Validation Loss:  15.24889
# Validation Accuracy: 40.31008%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 589
# -------------------------------
# loss: 3.584107  [   50/  296]
# loss: 3.181697  [  250/  296]
# training loss: 20.00030
# Correct/Total: 55.0/129
# Validation Loss:  15.23160
# Validation Accuracy: 42.63566%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 590
# -------------------------------
# loss: 3.169461  [   50/  296]
# loss: 2.348042  [  250/  296]
# training loss: 19.09612
# Correct/Total: 55.0/129
# Validation Loss:  15.21353
# Validation Accuracy: 42.63566%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 591
# -------------------------------
# loss: 2.238541  [   50/  296]
# loss: 3.560005  [  250/  296]
# training loss: 18.09391
# Correct/Total: 56.0/129
# Validation Loss:  15.21614
# Validation Accuracy: 43.41085%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 592
# -------------------------------
# loss: 2.105936  [   50/  296]
# loss: 3.506327  [  250/  296]
# training loss: 18.85023
# Correct/Total: 55.0/129
# Validation Loss:  15.21763
# Validation Accuracy: 42.63566%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 593
# -------------------------------
# loss: 2.809261  [   50/  296]
# loss: 3.299043  [  250/  296]
# training loss: 18.41752
# Correct/Total: 57.0/129
# Validation Loss:  15.22388
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 594
# -------------------------------
# loss: 2.854726  [   50/  296]
# loss: 3.616764  [  250/  296]
# training loss: 17.83592
# Correct/Total: 57.0/129
# Validation Loss:  15.22605
# Validation Accuracy: 44.18605%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 595
# -------------------------------
# loss: 2.637793  [   50/  296]
# loss: 2.728601  [  250/  296]
# training loss: 19.03081
# Correct/Total: 54.0/129
# Validation Loss:  15.24091
# Validation Accuracy: 41.86047%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 596
# -------------------------------
# loss: 3.175574  [   50/  296]
# loss: 2.348067  [  250/  296]
# training loss: 18.79833
# Correct/Total: 56.0/129
# Validation Loss:  15.25818
# Validation Accuracy: 43.41085%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 597
# -------------------------------
# loss: 2.975610  [   50/  296]
# loss: 3.579728  [  250/  296]
# training loss: 20.98872
# Correct/Total: 55.0/129
# Validation Loss:  15.26333
# Validation Accuracy: 42.63566%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 598
# -------------------------------
# loss: 3.704967  [   50/  296]
# loss: 3.126657  [  250/  296]
# training loss: 21.25790
# Correct/Total: 55.0/129
# Validation Loss:  15.25809
# Validation Accuracy: 42.63566%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 599
# -------------------------------
# loss: 3.786969  [   50/  296]
# loss: 3.759812  [  250/  296]
# training loss: 21.32054
# Correct/Total: 55.0/129
# Validation Loss:  15.25644
# Validation Accuracy: 42.63566%
#
# Current Best Validation Accuracy: 44.96124%
#
# Epoch 600
# -------------------------------
# loss: 3.194850  [   50/  296]
# loss: 2.776750  [  250/  296]
# training loss: 19.49570
# Correct/Total: 53.0/129
# Validation Loss:  15.26325
# Validation Accuracy: 41.08527%
#
# Current Best Validation Accuracy: 44.96124%
#
# Done!
