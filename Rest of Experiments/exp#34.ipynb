# %%
# !pip install pytorch-metric-learning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-metric-learning
#   Downloading pytorch_metric_learning-2.1.2-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->pytorch-metric-learning) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->pytorch-metric-learning) (16.0.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->pytorch-metric-learning) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->pytorch-metric-learning) (1.3.0)
# Installing collected packages: pytorch-metric-learning
# Successfully installed pytorch-metric-learning-2.1.2

# %%
import os
import json
import zipfile
import subprocess
import shutil
import getpass
import math
import numpy
import pandas
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image,ImageReadMode
import matplotlib.pyplot as plt
import plotly.express as px
from pytorch_metric_learning import losses, regularizers
from torchsummary import summary

# %%
torch.manual_seed(20)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
# device = "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
dataset_save_dir = './dataset'

# %%
def one_hot_encode(val):
    arr = numpy.zeros((6,), dtype=int)
    arr[val] = 1
    return arr

def get_bucket_id(age):
  age_floor = int(age)
  if age_floor >= 0 and age_floor <= 5: return 0
  elif age_floor >= 6 and age_floor <= 12: return 1
  elif age_floor >= 13 and age_floor <= 19: return 2
  elif age_floor >= 20 and age_floor <= 29: return 3
  elif age_floor >= 30 and age_floor <= 59: return 4
  else: return 5

def get_ground_truth(age):
  return one_hot_encode(get_bucket_id(age))

# %%
def train(dataloader, model, optimizer, loss_function, loss_optimizer):
    torch.cuda.empty_cache()
    size = len(dataloader.dataset)
    model.train()
    loss_tot = 0.0
    num = 0
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Zeroing the gradients
        optimizer.zero_grad()
        loss_optimizer.zero_grad()

        # Get Embeddings
        embeddings = model(X)

        # Calculate Loss
        loss = loss_function(embeddings, y.argmax(1))

        # Backpropagation
        loss.backward()

        # Update
        optimizer.step()
        loss_optimizer.step()

        loss_tot += loss.item()
        num += 1
        
        X.cpu()
        y.cpu()

    # loss_tot /= num
    print(f'training loss: {(loss_tot):>0.5f}')

# %%
validation_accuracy = []
current_max_val_acc = 0.0
def validation(dataloader, model, loss_function):
    global current_max_val_acc
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    correct = 0
    totalsize = 0
    loss_tot = 0.0
    num = 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)

            # Forward With Logits
            embeddings = model(X)        
            logits = loss_function.get_logits(embeddings)
            predSoftmax = nn.Softmax(dim=1)(logits)
            loss = loss_function(embeddings,y.argmax(1))
            
            correct += (predSoftmax.argmax(1) == y.argmax(1)).sum().item()
            totalsize += predSoftmax.shape[0]
            loss_tot += loss.item()
            num += 1
            X.cpu()
            y.cpu()
            
    print(f"Correct/Total: {correct}/{totalsize}")
    correct /= totalsize
    validation_accuracy.append(correct*100)
    print(f"Validation Loss:  {(loss_tot):>0.5f}")
    print(f"Validation Accuracy: {(100*correct):>0.5f}%\n")
    current_max_val_acc = max(current_max_val_acc,100*correct)
    print(f"Current Best Validation Accuracy: {(current_max_val_acc):>0.5f}%\n")
    return loss_tot

# %%
class XRayToothDataset(Dataset):
    def __init__(self, cwd, img_dir, transform=None, target_height=None, target_width=None):
        self.dataset_path = cwd + '/' + img_dir
        self.transform = transform
        self.target_height = target_height
        self.target_width = target_width

    def __len__(self):
        return len(os.listdir(self.dataset_path))

    def __getitem__(self, idx):
        if idx  >= len(os.listdir(self.dataset_path)):
            print("No datafile/image at index : "+ str(idx))
            return None
        img_filename = os.listdir(self.dataset_path)[idx]
        age = float(img_filename.split("_")[1][:-4])
        age_gt = get_ground_truth(age)
        image_tensor = read_image(path=self.dataset_path + '/' + img_filename)
        image_tensor = image_tensor.reshape(1, 3, image_tensor.shape[-2], image_tensor.shape[-1])
        if self.target_height and self.target_width: # Resize the image 
            image_tensor = torch.nn.functional.interpolate(image_tensor, (self.target_height,self.target_width))
        if self.transform: image_tensor = self.transform(image_tensor) # Apply transformations
        image_tensor = (image_tensor-image_tensor.min())/(image_tensor.max()-image_tensor.min())
        return image_tensor.reshape(-1,image_tensor.shape[-2],image_tensor.shape[-1]).to(torch.float32), torch.tensor(age_gt)

# %%
# Data Augmentation Transformations 
data_augmentation_transformations = T.RandomChoice([
    T.RandomAffine(degrees=0), # No Augmentation
    T.Lambda(lambda x: TF.hflip(img=x)) # Horizontal Flip

    # Geometric Transformations:
    # T.RandomAffine(degrees=0, scale=(1.3,1.3)), # Scale
    # T.RandomAffine(degrees=0, translate=(0.5,0.5)), # Translate
    # T.RandomAffine(degrees=(-8, 8)), # Rotate
    # T.Lambda(lambda x: TF.hflip(img=x)), # Reflect

    # Occlusion:
    # T.Compose([T.RandomErasing(p=1, scale=(0.0008, 0.0008), ratio=(1,1))]*100), # Occlusion

    # Intensity Operations
    # T.Lambda(lambda x: TF.adjust_gamma(img=x, gamma=0.5)), # Gamma Contrast
    # T.Lambda(lambda x: TF.adjust_contrast(x, contrast_factor=2.0)), # Linear Contrast

    # Filtering:
    # T.Lambda(lambda x: TF.adjust_sharpness(img=x, sharpness_factor=4)), #Sharpen
    # T.GaussianBlur(kernel_size=(15,15), sigma=(0.01, 1)), # Gaussian Blur
])

# %%
training_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/training', transform=data_augmentation_transformations, target_height=224, target_width=224)
validation_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/validation', transform=None, target_height=224, target_width=224)

# %%
from torchvision.models import vit_l_16, ViT_L_16_Weights

pretrained_vit = vit_l_16(weights=ViT_L_16_Weights.IMAGENET1K_V1)
# Out:
# Downloading: "https://download.pytorch.org/models/vit_l_16-852ce7e3.pth" to /root/.cache/torch/hub/checkpoints/vit_l_16-852ce7e3.pth
# 100%|██████████| 1.13G/1.13G [02:56<00:00, 6.90MB/s]

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = pretrained_vit

        for param in self.backbone.parameters():
            param.requires_grad = False

        self.fc = nn.Sequential(
            nn.Dropout(0.6),
            nn.Linear(1000,512),
            nn.ReLU(),
            nn.Dropout(0.6),
            nn.Linear(512,256)
        )
    
    def forward(self, x):
        x = self.backbone(x)
        x = self.fc(x)
        return x

# %%
model = NeuralNetwork().to(device)

# %%
# Test a forward pass
with torch.no_grad():
    print(model(training_data[0][0].reshape(-1,3,224,224).to(device)))
# Out:
# tensor([[ 0.7060, -0.5324, -1.0112, -0.0208, -0.0304,  1.0278,  0.0583,  0.0226,
#          -0.2991, -1.1038, -1.1469, -0.7054, -0.6472,  0.1490, -0.6505,  0.5853,
#           0.3261, -0.0598, -0.3148,  0.0756,  0.6761, -0.3087,  0.4559, -0.5676,
#           0.1531, -0.7001,  0.6314,  0.3357, -0.5995, -0.9161,  0.2240,  0.5413,
#           0.2095,  0.3496,  0.1497,  0.3920,  1.0071, -0.7822,  0.0518, -0.2186,
#           0.3826,  0.5794,  0.4597,  0.1776, -0.1511,  0.1141,  0.4110,  0.0198,
#           0.5181,  0.5171, -0.4333, -0.1782,  0.9229, -1.4627, -0.2802, -0.2986,
#          -0.0960, -0.4371, -0.4181, -1.2767, -0.4452, -0.4951, -0.5077,  0.5046,
#           0.2551,  1.4527,  0.0233,  0.2348, -0.4866,  0.0334, -0.0776,  0.7927,
#           0.5865,  0.6771, -0.2389,  0.4178, -0.3662, -0.4308,  0.5583,  0.9516,
#           0.2938,  0.2525,  0.1182,  0.1552,  0.0258,  0.2353,  0.5592, -0.5535,
#          -0.1996,  0.3261,  0.0274, -0.4359, -0.4269,  1.1238, -0.5981,  0.1346,
#           0.0400, -0.3091, -0.1786,  0.8238, -0.1389,  0.3681,  0.1408, -0.0952,
#          -0.1958, -0.1962,  0.3485, -0.3468, -0.4335,  0.4094,  0.1357, -0.0361,
#           0.8198, -0.5754,  0.5336, -0.5053, -0.1395,  0.7927, -1.0499, -0.0329,
#           0.1291, -0.7596, -0.7902,  0.3307,  0.1087, -1.5507, -0.4217,  1.3856,
#           0.2492,  0.1524,  0.4733,  0.2196,  0.6599, -0.2668, -0.8142, -0.7194,
#           0.8444, -1.0469, -0.0917, -0.2048, -0.1564,  0.8347, -0.2733, -0.3040,
#          -0.2992,  0.5673,  0.2457,  0.6138, -0.2778,  0.1256,  1.1789,  0.2800,
#          -0.4282,  0.4195,  0.7358,  0.9798,  0.0472, -0.2594,  1.1639,  0.2464,
#          -0.2628,  0.7410,  0.3972, -0.2982, -0.0551,  0.0891, -0.2110, -0.8332,
#          -0.6252,  0.1913, -0.0138, -1.2132,  0.4344, -0.2325, -0.5047, -0.7361,
#          -0.1500, -0.4989, -0.8297, -0.8950, -0.8417,  0.2869, -0.4050,  0.5858,
#          -0.0318,  0.0627,  0.0763, -0.1859, -0.1094, -0.5041,  0.2149, -0.1941,
#           0.2697, -0.3489,  0.6338,  0.5062,  0.5944,  0.3778,  0.3225,  0.7125,
#           0.4086,  0.4558,  0.0557, -0.2790, -1.2312, -0.7133,  0.4756, -0.0069,
#          -0.9209,  0.3320,  1.1527, -0.3410, -0.2498, -1.4433,  0.2890, -0.3069,
#          -0.8072,  0.3042,  0.5832, -0.1955,  0.7124,  0.3981,  0.3950, -0.4601,
#          -0.0907, -0.6490, -0.3760, -0.9758, -0.2023,  0.1399,  0.4581,  0.5733,
#           0.8909, -0.5460, -0.4346, -0.0595,  0.7516,  0.1648,  1.6441,  0.7164,
#           0.1070, -0.5468, -0.2663,  0.5178,  0.4624,  0.0772, -0.0550,  0.4569,
#          -0.0822, -0.2908,  0.7404, -0.6549, -0.4556,  0.8357,  0.0788,  0.1269]],
#        device='cuda:0')

# %%
# Training Hyperparameters
epochs = 500
batch_size = 10
learning_rate = 1e-2
momentum=0.9
weight_decay=0.05

# Margin Loss Hyperparameters
margin_loss_learning_rate = 9e-1

# %%
training_data_loader = DataLoader(training_data, batch_size, shuffle = True)
validation_data_loader = DataLoader(validation_data, batch_size, shuffle = False)

# %%
# Loss
margin_loss_regularizer = regularizers.RegularFaceRegularizer()
margin_loss_function = losses.ArcFaceLoss(6, 256, margin=34.3, scale=1, weight_regularizer=margin_loss_regularizer).to(device)

# %%
# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
loss_optimizer = torch.optim.SGD(margin_loss_function.parameters(), lr=margin_loss_learning_rate)

# Schedulers
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=5, min_lr=1e-5,verbose=True)
margin_loss_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=5, min_lr=1e-5,verbose=True)

# %%
# Training
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data_loader, model, optimizer, margin_loss_function, loss_optimizer)
    val_loss = validation(validation_data_loader, model, margin_loss_function)
    scheduler.step(val_loss)
    margin_loss_scheduler.step(val_loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# training loss: 57.91638
# Correct/Total: 67/129
# Validation Loss:  24.17263
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 2
# -------------------------------
# training loss: 55.36585
# Correct/Total: 67/129
# Validation Loss:  23.63321
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 3
# -------------------------------
# training loss: 53.99397
# Correct/Total: 67/129
# Validation Loss:  23.15780
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 4
# -------------------------------
# training loss: 51.92327
# Correct/Total: 68/129
# Validation Loss:  22.45345
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 52.71318%
#
# Epoch 5
# -------------------------------
# training loss: 50.93818
# Correct/Total: 75/129
# Validation Loss:  21.65317
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 6
# -------------------------------
# training loss: 48.74756
# Correct/Total: 72/129
# Validation Loss:  21.18767
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 7
# -------------------------------
# training loss: 47.85029
# Correct/Total: 74/129
# Validation Loss:  21.23867
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 58.13953%
#
# Epoch 8
# -------------------------------
# training loss: 47.04662
# Correct/Total: 81/129
# Validation Loss:  20.37553
# Validation Accuracy: 62.79070%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 9
# -------------------------------
# training loss: 46.08889
# Correct/Total: 78/129
# Validation Loss:  20.42237
# Validation Accuracy: 60.46512%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 10
# -------------------------------
# training loss: 46.13601
# Correct/Total: 80/129
# Validation Loss:  20.08810
# Validation Accuracy: 62.01550%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 11
# -------------------------------
# training loss: 45.50033
# Correct/Total: 77/129
# Validation Loss:  20.11765
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 12
# -------------------------------
# training loss: 44.27978
# Correct/Total: 77/129
# Validation Loss:  20.00154
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 13
# -------------------------------
# training loss: 42.89615
# Correct/Total: 77/129
# Validation Loss:  20.17447
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 14
# -------------------------------
# training loss: 43.40070
# Correct/Total: 74/129
# Validation Loss:  20.07831
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 15
# -------------------------------
# training loss: 42.58291
# Correct/Total: 74/129
# Validation Loss:  19.77855
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 16
# -------------------------------
# training loss: 41.06948
# Correct/Total: 75/129
# Validation Loss:  19.65418
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 17
# -------------------------------
# training loss: 41.63722
# Correct/Total: 77/129
# Validation Loss:  19.25700
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 18
# -------------------------------
# training loss: 41.90280
# Correct/Total: 73/129
# Validation Loss:  19.64055
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 19
# -------------------------------
# training loss: 39.08409
# Correct/Total: 76/129
# Validation Loss:  18.91498
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 20
# -------------------------------
# training loss: 40.45031
# Correct/Total: 76/129
# Validation Loss:  19.25754
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 21
# -------------------------------
# training loss: 41.02321
# Correct/Total: 74/129
# Validation Loss:  19.29527
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 22
# -------------------------------
# training loss: 39.35034
# Correct/Total: 77/129
# Validation Loss:  19.47926
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 23
# -------------------------------
# training loss: 39.78904
# Correct/Total: 73/129
# Validation Loss:  19.31871
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 24
# -------------------------------
# training loss: 39.20509
# Correct/Total: 72/129
# Validation Loss:  19.19337
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 25
# -------------------------------
# training loss: 40.26412
# Correct/Total: 72/129
# Validation Loss:  19.10528
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00025: reducing learning rate of group 0 to 9.0000e-03.
# Epoch 00025: reducing learning rate of group 0 to 8.1000e-03.
# Epoch 26
# -------------------------------
# training loss: 39.25734
# Correct/Total: 76/129
# Validation Loss:  18.96064
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 27
# -------------------------------
# training loss: 37.77232
# Correct/Total: 78/129
# Validation Loss:  18.92580
# Validation Accuracy: 60.46512%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 28
# -------------------------------
# training loss: 37.92567
# Correct/Total: 70/129
# Validation Loss:  19.02765
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 29
# -------------------------------
# training loss: 38.76094
# Correct/Total: 74/129
# Validation Loss:  18.91246
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 30
# -------------------------------
# training loss: 38.06037
# Correct/Total: 70/129
# Validation Loss:  19.35624
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 31
# -------------------------------
# training loss: 38.61908
# Correct/Total: 73/129
# Validation Loss:  19.21885
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 32
# -------------------------------
# training loss: 37.97222
# Correct/Total: 71/129
# Validation Loss:  19.40297
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 33
# -------------------------------
# training loss: 36.84938
# Correct/Total: 79/129
# Validation Loss:  18.86965
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 34
# -------------------------------
# training loss: 36.97168
# Correct/Total: 73/129
# Validation Loss:  19.24824
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 35
# -------------------------------
# training loss: 37.38889
# Correct/Total: 73/129
# Validation Loss:  19.12573
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 36
# -------------------------------
# training loss: 36.27021
# Correct/Total: 71/129
# Validation Loss:  19.39241
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 37
# -------------------------------
# training loss: 35.88448
# Correct/Total: 72/129
# Validation Loss:  19.23434
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 38
# -------------------------------
# training loss: 36.74910
# Correct/Total: 80/129
# Validation Loss:  18.83096
# Validation Accuracy: 62.01550%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 39
# -------------------------------
# training loss: 36.54762
# Correct/Total: 72/129
# Validation Loss:  19.14635
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 40
# -------------------------------
# training loss: 36.59842
# Correct/Total: 73/129
# Validation Loss:  18.94593
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 41
# -------------------------------
# training loss: 35.56018
# Correct/Total: 76/129
# Validation Loss:  18.96985
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 42
# -------------------------------
# training loss: 35.91575
# Correct/Total: 76/129
# Validation Loss:  18.79532
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 43
# -------------------------------
# training loss: 37.19642
# Correct/Total: 70/129
# Validation Loss:  19.27172
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 44
# -------------------------------
# training loss: 36.32981
# Correct/Total: 77/129
# Validation Loss:  18.76420
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 45
# -------------------------------
# training loss: 34.99570
# Correct/Total: 74/129
# Validation Loss:  18.97864
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 46
# -------------------------------
# training loss: 36.22011
# Correct/Total: 76/129
# Validation Loss:  18.79167
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 47
# -------------------------------
# training loss: 35.84118
# Correct/Total: 71/129
# Validation Loss:  19.10050
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 48
# -------------------------------
# training loss: 35.30031
# Correct/Total: 74/129
# Validation Loss:  19.05738
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 49
# -------------------------------
# training loss: 36.64935
# Correct/Total: 74/129
# Validation Loss:  18.90583
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 50
# -------------------------------
# training loss: 36.30767
# Correct/Total: 75/129
# Validation Loss:  18.85342
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00050: reducing learning rate of group 0 to 7.2900e-03.
# Epoch 00050: reducing learning rate of group 0 to 6.5610e-03.
# Epoch 51
# -------------------------------
# training loss: 35.48972
# Correct/Total: 76/129
# Validation Loss:  18.58918
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 52
# -------------------------------
# training loss: 35.39012
# Correct/Total: 79/129
# Validation Loss:  18.52430
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 53
# -------------------------------
# training loss: 35.05386
# Correct/Total: 80/129
# Validation Loss:  18.52739
# Validation Accuracy: 62.01550%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 54
# -------------------------------
# training loss: 33.79002
# Correct/Total: 73/129
# Validation Loss:  19.12636
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 55
# -------------------------------
# training loss: 34.41884
# Correct/Total: 77/129
# Validation Loss:  18.77960
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 56
# -------------------------------
# training loss: 34.24553
# Correct/Total: 76/129
# Validation Loss:  18.89147
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 57
# -------------------------------
# training loss: 35.01409
# Correct/Total: 72/129
# Validation Loss:  18.88332
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 58
# -------------------------------
# training loss: 35.10005
# Correct/Total: 74/129
# Validation Loss:  18.90868
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00058: reducing learning rate of group 0 to 5.9049e-03.
# Epoch 00058: reducing learning rate of group 0 to 5.3144e-03.
# Epoch 59
# -------------------------------
# training loss: 34.60480
# Correct/Total: 77/129
# Validation Loss:  18.71831
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 60
# -------------------------------
# training loss: 35.48081
# Correct/Total: 75/129
# Validation Loss:  18.64783
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 61
# -------------------------------
# training loss: 35.20057
# Correct/Total: 74/129
# Validation Loss:  18.80923
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 62
# -------------------------------
# training loss: 33.82148
# Correct/Total: 75/129
# Validation Loss:  18.86683
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 63
# -------------------------------
# training loss: 33.93882
# Correct/Total: 79/129
# Validation Loss:  18.48400
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 64
# -------------------------------
# training loss: 33.68709
# Correct/Total: 78/129
# Validation Loss:  18.64628
# Validation Accuracy: 60.46512%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 65
# -------------------------------
# training loss: 33.88894
# Correct/Total: 77/129
# Validation Loss:  18.58789
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 66
# -------------------------------
# training loss: 34.36375
# Correct/Total: 79/129
# Validation Loss:  18.69978
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 67
# -------------------------------
# training loss: 34.92636
# Correct/Total: 79/129
# Validation Loss:  18.57855
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 68
# -------------------------------
# training loss: 34.48750
# Correct/Total: 76/129
# Validation Loss:  18.45412
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 69
# -------------------------------
# training loss: 33.43226
# Correct/Total: 80/129
# Validation Loss:  18.46962
# Validation Accuracy: 62.01550%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 70
# -------------------------------
# training loss: 33.78222
# Correct/Total: 77/129
# Validation Loss:  18.85288
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 71
# -------------------------------
# training loss: 34.70695
# Correct/Total: 75/129
# Validation Loss:  18.98002
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 72
# -------------------------------
# training loss: 33.85680
# Correct/Total: 74/129
# Validation Loss:  18.93666
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 73
# -------------------------------
# training loss: 33.83461
# Correct/Total: 77/129
# Validation Loss:  18.81228
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 74
# -------------------------------
# training loss: 32.89363
# Correct/Total: 77/129
# Validation Loss:  18.72159
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00074: reducing learning rate of group 0 to 4.7830e-03.
# Epoch 00074: reducing learning rate of group 0 to 4.3047e-03.
# Epoch 75
# -------------------------------
# training loss: 33.39486
# Correct/Total: 78/129
# Validation Loss:  18.88112
# Validation Accuracy: 60.46512%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 76
# -------------------------------
# training loss: 32.30354
# Correct/Total: 71/129
# Validation Loss:  19.18211
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 77
# -------------------------------
# training loss: 33.27983
# Correct/Total: 74/129
# Validation Loss:  19.05923
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 78
# -------------------------------
# training loss: 32.83253
# Correct/Total: 79/129
# Validation Loss:  18.70158
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 79
# -------------------------------
# training loss: 32.98553
# Correct/Total: 76/129
# Validation Loss:  18.69434
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 80
# -------------------------------
# training loss: 33.23255
# Correct/Total: 76/129
# Validation Loss:  18.57303
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00080: reducing learning rate of group 0 to 3.8742e-03.
# Epoch 00080: reducing learning rate of group 0 to 3.4868e-03.
# Epoch 81
# -------------------------------
# training loss: 32.73849
# Correct/Total: 78/129
# Validation Loss:  18.69342
# Validation Accuracy: 60.46512%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 82
# -------------------------------
# training loss: 34.79379
# Correct/Total: 75/129
# Validation Loss:  19.00025
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 83
# -------------------------------
# training loss: 32.60132
# Correct/Total: 76/129
# Validation Loss:  18.77418
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 84
# -------------------------------
# training loss: 33.21946
# Correct/Total: 71/129
# Validation Loss:  19.11556
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 85
# -------------------------------
# training loss: 32.90365
# Correct/Total: 73/129
# Validation Loss:  19.00229
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 86
# -------------------------------
# training loss: 33.23514
# Correct/Total: 75/129
# Validation Loss:  18.64582
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00086: reducing learning rate of group 0 to 3.1381e-03.
# Epoch 00086: reducing learning rate of group 0 to 2.8243e-03.
# Epoch 87
# -------------------------------
# training loss: 32.73150
# Correct/Total: 78/129
# Validation Loss:  18.85923
# Validation Accuracy: 60.46512%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 88
# -------------------------------
# training loss: 32.16381
# Correct/Total: 77/129
# Validation Loss:  18.85494
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 89
# -------------------------------
# training loss: 31.99137
# Correct/Total: 77/129
# Validation Loss:  18.72851
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 90
# -------------------------------
# training loss: 31.81055
# Correct/Total: 77/129
# Validation Loss:  18.98058
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 91
# -------------------------------
# training loss: 32.32548
# Correct/Total: 75/129
# Validation Loss:  19.13428
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 92
# -------------------------------
# training loss: 32.01053
# Correct/Total: 73/129
# Validation Loss:  19.10032
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00092: reducing learning rate of group 0 to 2.5419e-03.
# Epoch 00092: reducing learning rate of group 0 to 2.2877e-03.
# Epoch 93
# -------------------------------
# training loss: 31.88229
# Correct/Total: 75/129
# Validation Loss:  18.89847
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 94
# -------------------------------
# training loss: 31.57242
# Correct/Total: 76/129
# Validation Loss:  19.06876
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 95
# -------------------------------
# training loss: 30.82928
# Correct/Total: 71/129
# Validation Loss:  19.09020
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 96
# -------------------------------
# training loss: 31.76447
# Correct/Total: 71/129
# Validation Loss:  19.12051
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 97
# -------------------------------
# training loss: 31.21204
# Correct/Total: 74/129
# Validation Loss:  19.01484
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 98
# -------------------------------
# training loss: 32.79314
# Correct/Total: 74/129
# Validation Loss:  18.93324
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00098: reducing learning rate of group 0 to 2.0589e-03.
# Epoch 00098: reducing learning rate of group 0 to 1.8530e-03.
# Epoch 99
# -------------------------------
# training loss: 31.87800
# Correct/Total: 73/129
# Validation Loss:  18.95815
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 100
# -------------------------------
# training loss: 32.44449
# Correct/Total: 73/129
# Validation Loss:  19.02371
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 101
# -------------------------------
# training loss: 32.48552
# Correct/Total: 74/129
# Validation Loss:  18.97291
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 102
# -------------------------------
# training loss: 32.62133
# Correct/Total: 75/129
# Validation Loss:  18.86359
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 103
# -------------------------------
# training loss: 32.21468
# Correct/Total: 72/129
# Validation Loss:  19.12939
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 104
# -------------------------------
# training loss: 32.25277
# Correct/Total: 74/129
# Validation Loss:  19.09005
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00104: reducing learning rate of group 0 to 1.6677e-03.
# Epoch 00104: reducing learning rate of group 0 to 1.5009e-03.
# Epoch 105
# -------------------------------
# training loss: 32.27806
# Correct/Total: 73/129
# Validation Loss:  19.07553
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 106
# -------------------------------
# training loss: 31.34262
# Correct/Total: 74/129
# Validation Loss:  19.19020
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 107
# -------------------------------
# training loss: 31.79436
# Correct/Total: 72/129
# Validation Loss:  19.24719
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 108
# -------------------------------
# training loss: 32.80663
# Correct/Total: 73/129
# Validation Loss:  19.34771
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 109
# -------------------------------
# training loss: 31.34548
# Correct/Total: 75/129
# Validation Loss:  19.30122
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 110
# -------------------------------
# training loss: 31.66795
# Correct/Total: 76/129
# Validation Loss:  19.11655
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00110: reducing learning rate of group 0 to 1.3509e-03.
# Epoch 00110: reducing learning rate of group 0 to 1.2158e-03.
# Epoch 111
# -------------------------------
# training loss: 32.80940
# Correct/Total: 77/129
# Validation Loss:  18.85726
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 112
# -------------------------------
# training loss: 32.12476
# Correct/Total: 77/129
# Validation Loss:  18.91638
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 113
# -------------------------------
# training loss: 29.98878
# Correct/Total: 78/129
# Validation Loss:  18.89057
# Validation Accuracy: 60.46512%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 114
# -------------------------------
# training loss: 32.45667
# Correct/Total: 79/129
# Validation Loss:  18.73761
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 115
# -------------------------------
# training loss: 31.73333
# Correct/Total: 79/129
# Validation Loss:  18.76481
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 116
# -------------------------------
# training loss: 32.63046
# Correct/Total: 75/129
# Validation Loss:  18.94855
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00116: reducing learning rate of group 0 to 1.0942e-03.
# Epoch 00116: reducing learning rate of group 0 to 9.8477e-04.
# Epoch 117
# -------------------------------
# training loss: 32.15485
# Correct/Total: 73/129
# Validation Loss:  19.17261
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 118
# -------------------------------
# training loss: 30.56132
# Correct/Total: 72/129
# Validation Loss:  19.27580
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 119
# -------------------------------
# training loss: 31.25263
# Correct/Total: 72/129
# Validation Loss:  19.27523
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 120
# -------------------------------
# training loss: 31.84795
# Correct/Total: 73/129
# Validation Loss:  19.34075
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 121
# -------------------------------
# training loss: 30.74155
# Correct/Total: 74/129
# Validation Loss:  19.23080
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 122
# -------------------------------
# training loss: 31.86020
# Correct/Total: 73/129
# Validation Loss:  19.24495
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00122: reducing learning rate of group 0 to 8.8629e-04.
# Epoch 00122: reducing learning rate of group 0 to 7.9766e-04.
# Epoch 123
# -------------------------------
# training loss: 30.62301
# Correct/Total: 75/129
# Validation Loss:  19.24250
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 124
# -------------------------------
# training loss: 31.00417
# Correct/Total: 76/129
# Validation Loss:  19.20719
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 125
# -------------------------------
# training loss: 31.22510
# Correct/Total: 77/129
# Validation Loss:  19.00232
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 126
# -------------------------------
# training loss: 30.67503
# Correct/Total: 77/129
# Validation Loss:  18.97201
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 127
# -------------------------------
# training loss: 31.97290
# Correct/Total: 76/129
# Validation Loss:  18.95437
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 128
# -------------------------------
# training loss: 31.91416
# Correct/Total: 74/129
# Validation Loss:  19.00884
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00128: reducing learning rate of group 0 to 7.1790e-04.
# Epoch 00128: reducing learning rate of group 0 to 6.4611e-04.
# Epoch 129
# -------------------------------
# training loss: 30.38257
# Correct/Total: 74/129
# Validation Loss:  19.05908
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 130
# -------------------------------
# training loss: 31.73481
# Correct/Total: 76/129
# Validation Loss:  19.01094
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 131
# -------------------------------
# training loss: 31.63622
# Correct/Total: 75/129
# Validation Loss:  18.98985
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 132
# -------------------------------
# training loss: 30.60268
# Correct/Total: 77/129
# Validation Loss:  18.97170
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 133
# -------------------------------
# training loss: 31.07727
# Correct/Total: 75/129
# Validation Loss:  18.99888
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 134
# -------------------------------
# training loss: 32.37708
# Correct/Total: 74/129
# Validation Loss:  19.02279
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00134: reducing learning rate of group 0 to 5.8150e-04.
# Epoch 00134: reducing learning rate of group 0 to 5.2335e-04.
# Epoch 135
# -------------------------------
# training loss: 32.81673
# Correct/Total: 73/129
# Validation Loss:  19.00656
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 136
# -------------------------------
# training loss: 32.18421
# Correct/Total: 76/129
# Validation Loss:  18.88627
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 137
# -------------------------------
# training loss: 30.89734
# Correct/Total: 77/129
# Validation Loss:  18.67728
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 138
# -------------------------------
# training loss: 29.80856
# Correct/Total: 79/129
# Validation Loss:  18.67172
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 139
# -------------------------------
# training loss: 31.76977
# Correct/Total: 79/129
# Validation Loss:  18.70983
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 140
# -------------------------------
# training loss: 30.48365
# Correct/Total: 79/129
# Validation Loss:  18.61411
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00140: reducing learning rate of group 0 to 4.7101e-04.
# Epoch 00140: reducing learning rate of group 0 to 4.2391e-04.
# Epoch 141
# -------------------------------
# training loss: 31.48407
# Correct/Total: 79/129
# Validation Loss:  18.68163
# Validation Accuracy: 61.24031%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 142
# -------------------------------
# training loss: 32.78264
# Correct/Total: 77/129
# Validation Loss:  18.73558
# Validation Accuracy: 59.68992%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 143
# -------------------------------
# training loss: 31.24999
# Correct/Total: 75/129
# Validation Loss:  18.87690
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 144
# -------------------------------
# training loss: 31.57459
# Correct/Total: 74/129
# Validation Loss:  18.89825
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 145
# -------------------------------
# training loss: 30.87185
# Correct/Total: 74/129
# Validation Loss:  18.96154
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 146
# -------------------------------
# training loss: 31.74104
# Correct/Total: 73/129
# Validation Loss:  18.96834
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00146: reducing learning rate of group 0 to 3.8152e-04.
# Epoch 00146: reducing learning rate of group 0 to 3.4337e-04.
# Epoch 147
# -------------------------------
# training loss: 32.02478
# Correct/Total: 73/129
# Validation Loss:  18.98589
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 148
# -------------------------------
# training loss: 30.77028
# Correct/Total: 73/129
# Validation Loss:  19.01470
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 149
# -------------------------------
# training loss: 30.79238
# Correct/Total: 73/129
# Validation Loss:  19.08879
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 150
# -------------------------------
# training loss: 29.84497
# Correct/Total: 73/129
# Validation Loss:  19.11725
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 151
# -------------------------------
# training loss: 32.48927
# Correct/Total: 73/129
# Validation Loss:  19.12728
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 152
# -------------------------------
# training loss: 31.20986
# Correct/Total: 73/129
# Validation Loss:  19.14954
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00152: reducing learning rate of group 0 to 3.0903e-04.
# Epoch 00152: reducing learning rate of group 0 to 2.7813e-04.
# Epoch 153
# -------------------------------
# training loss: 30.03553
# Correct/Total: 74/129
# Validation Loss:  19.18358
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 154
# -------------------------------
# training loss: 31.70259
# Correct/Total: 73/129
# Validation Loss:  19.18611
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 155
# -------------------------------
# training loss: 30.43598
# Correct/Total: 73/129
# Validation Loss:  19.20149
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 156
# -------------------------------
# training loss: 31.37330
# Correct/Total: 72/129
# Validation Loss:  19.13496
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 157
# -------------------------------
# training loss: 31.42120
# Correct/Total: 72/129
# Validation Loss:  19.16208
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 158
# -------------------------------
# training loss: 31.41280
# Correct/Total: 72/129
# Validation Loss:  19.22435
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00158: reducing learning rate of group 0 to 2.5032e-04.
# Epoch 00158: reducing learning rate of group 0 to 2.2528e-04.
# Epoch 159
# -------------------------------
# training loss: 32.06331
# Correct/Total: 72/129
# Validation Loss:  19.23620
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 160
# -------------------------------
# training loss: 30.21604
# Correct/Total: 72/129
# Validation Loss:  19.24239
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 161
# -------------------------------
# training loss: 30.85287
# Correct/Total: 72/129
# Validation Loss:  19.24522
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 162
# -------------------------------
# training loss: 30.85087
# Correct/Total: 72/129
# Validation Loss:  19.24551
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 163
# -------------------------------
# training loss: 31.69358
# Correct/Total: 72/129
# Validation Loss:  19.25790
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 164
# -------------------------------
# training loss: 30.82281
# Correct/Total: 71/129
# Validation Loss:  19.26592
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00164: reducing learning rate of group 0 to 2.0276e-04.
# Epoch 00164: reducing learning rate of group 0 to 1.8248e-04.
# Epoch 165
# -------------------------------
# training loss: 31.40627
# Correct/Total: 71/129
# Validation Loss:  19.26340
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 166
# -------------------------------
# training loss: 30.63774
# Correct/Total: 71/129
# Validation Loss:  19.24201
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 167
# -------------------------------
# training loss: 31.57358
# Correct/Total: 71/129
# Validation Loss:  19.20797
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 168
# -------------------------------
# training loss: 31.59115
# Correct/Total: 71/129
# Validation Loss:  19.14115
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 169
# -------------------------------
# training loss: 31.37992
# Correct/Total: 74/129
# Validation Loss:  19.11900
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 170
# -------------------------------
# training loss: 31.70755
# Correct/Total: 73/129
# Validation Loss:  19.10781
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00170: reducing learning rate of group 0 to 1.6423e-04.
# Epoch 00170: reducing learning rate of group 0 to 1.4781e-04.
# Epoch 171
# -------------------------------
# training loss: 30.82049
# Correct/Total: 73/129
# Validation Loss:  19.10412
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 172
# -------------------------------
# training loss: 30.71121
# Correct/Total: 73/129
# Validation Loss:  19.06702
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 173
# -------------------------------
# training loss: 31.90105
# Correct/Total: 72/129
# Validation Loss:  19.06502
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 174
# -------------------------------
# training loss: 31.83678
# Correct/Total: 75/129
# Validation Loss:  19.02851
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 175
# -------------------------------
# training loss: 31.38571
# Correct/Total: 75/129
# Validation Loss:  19.05389
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 176
# -------------------------------
# training loss: 31.90741
# Correct/Total: 75/129
# Validation Loss:  19.11386
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00176: reducing learning rate of group 0 to 1.3303e-04.
# Epoch 00176: reducing learning rate of group 0 to 1.1973e-04.
# Epoch 177
# -------------------------------
# training loss: 31.10018
# Correct/Total: 73/129
# Validation Loss:  19.14395
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 178
# -------------------------------
# training loss: 30.84757
# Correct/Total: 73/129
# Validation Loss:  19.16573
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 179
# -------------------------------
# training loss: 31.15463
# Correct/Total: 75/129
# Validation Loss:  19.17632
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 180
# -------------------------------
# training loss: 30.28230
# Correct/Total: 75/129
# Validation Loss:  19.16246
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 181
# -------------------------------
# training loss: 29.74791
# Correct/Total: 75/129
# Validation Loss:  19.15341
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 182
# -------------------------------
# training loss: 31.55019
# Correct/Total: 74/129
# Validation Loss:  19.16732
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00182: reducing learning rate of group 0 to 1.0775e-04.
# Epoch 00182: reducing learning rate of group 0 to 9.6977e-05.
# Epoch 183
# -------------------------------
# training loss: 30.77639
# Correct/Total: 74/129
# Validation Loss:  19.18019
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 184
# -------------------------------
# training loss: 31.35546
# Correct/Total: 74/129
# Validation Loss:  19.18803
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 185
# -------------------------------
# training loss: 31.37621
# Correct/Total: 74/129
# Validation Loss:  19.20215
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 186
# -------------------------------
# training loss: 30.61391
# Correct/Total: 74/129
# Validation Loss:  19.20034
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 187
# -------------------------------
# training loss: 31.43284
# Correct/Total: 73/129
# Validation Loss:  19.20604
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 188
# -------------------------------
# training loss: 31.39085
# Correct/Total: 71/129
# Validation Loss:  19.22795
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00188: reducing learning rate of group 0 to 8.7280e-05.
# Epoch 00188: reducing learning rate of group 0 to 7.8552e-05.
# Epoch 189
# -------------------------------
# training loss: 30.57022
# Correct/Total: 71/129
# Validation Loss:  19.24092
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 190
# -------------------------------
# training loss: 30.25411
# Correct/Total: 71/129
# Validation Loss:  19.24102
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 191
# -------------------------------
# training loss: 31.41339
# Correct/Total: 70/129
# Validation Loss:  19.25590
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 192
# -------------------------------
# training loss: 30.88164
# Correct/Total: 72/129
# Validation Loss:  19.23500
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 193
# -------------------------------
# training loss: 31.73666
# Correct/Total: 71/129
# Validation Loss:  19.23466
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 194
# -------------------------------
# training loss: 30.14779
# Correct/Total: 71/129
# Validation Loss:  19.24826
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00194: reducing learning rate of group 0 to 7.0697e-05.
# Epoch 00194: reducing learning rate of group 0 to 6.3627e-05.
# Epoch 195
# -------------------------------
# training loss: 29.94493
# Correct/Total: 71/129
# Validation Loss:  19.25150
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 196
# -------------------------------
# training loss: 31.16595
# Correct/Total: 72/129
# Validation Loss:  19.24470
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 197
# -------------------------------
# training loss: 31.49001
# Correct/Total: 72/129
# Validation Loss:  19.24838
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 198
# -------------------------------
# training loss: 31.08574
# Correct/Total: 71/129
# Validation Loss:  19.26506
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 199
# -------------------------------
# training loss: 30.59647
# Correct/Total: 72/129
# Validation Loss:  19.26493
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 200
# -------------------------------
# training loss: 31.69162
# Correct/Total: 72/129
# Validation Loss:  19.25208
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00200: reducing learning rate of group 0 to 5.7264e-05.
# Epoch 00200: reducing learning rate of group 0 to 5.1538e-05.
# Epoch 201
# -------------------------------
# training loss: 30.82941
# Correct/Total: 72/129
# Validation Loss:  19.25916
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 202
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 203
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 204
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 205
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 206
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00206: reducing learning rate of group 0 to 4.6384e-05.
# Epoch 00206: reducing learning rate of group 0 to 4.1746e-05.
# Epoch 207
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 208
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 209
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 210
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 211
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 212
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00212: reducing learning rate of group 0 to 3.7571e-05.
# Epoch 00212: reducing learning rate of group 0 to 3.3814e-05.
# Epoch 213
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 214
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 215
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 216
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 217
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 218
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00218: reducing learning rate of group 0 to 3.0433e-05.
# Epoch 00218: reducing learning rate of group 0 to 2.7389e-05.
# Epoch 219
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 220
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 221
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 222
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 223
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 224
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00224: reducing learning rate of group 0 to 2.4650e-05.
# Epoch 00224: reducing learning rate of group 0 to 2.2185e-05.
# Epoch 225
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 226
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 227
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 228
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 229
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 230
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 00230: reducing learning rate of group 0 to 1.9967e-05.
# Epoch 00230: reducing learning rate of group 0 to 1.7970e-05.
# Epoch 231
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 232
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 233
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 234
# ...
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 413
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 414
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 415
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 416
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 417
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 418
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 419
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 420
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 421
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 422
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 423
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 424
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 425
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 426
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 427
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 428
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 429
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 430
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 431
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 432
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 433
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 434
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 435
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 436
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 437
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 438
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 439
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 440
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 441
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 442
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 443
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 444
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 445
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 446
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 447
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 448
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 449
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 450
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 451
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 452
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 453
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 454
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 455
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 456
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 457
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 458
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 459
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 460
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 461
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 462
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 463
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 464
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 465
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 466
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 467
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 468
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 469
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 470
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 471
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 472
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 473
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 474
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 475
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 476
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 477
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 478
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 479
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 480
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 481
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 482
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 483
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 484
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 485
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 486
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 487
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 488
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 489
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 490
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 491
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 492
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 493
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 494
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 495
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 496
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 497
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 498
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 499
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Epoch 500
# -------------------------------
# training loss: nan
# Correct/Total: 5/129
# Validation Loss:  nan
# Validation Accuracy: 3.87597%
#
# Current Best Validation Accuracy: 62.79070%
#
# Done!

# %%
plt.plot(validation_accuracy)
