# %%
import os
import json
import zipfile
import subprocess
import shutil
import getpass
import math
import numpy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image,ImageReadMode
import matplotlib.pyplot as plt

# %%
torch.manual_seed(20)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
# device = "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# Dataset Configurations
dataset_save_dir = './dataset'

# %%
def one_hot_encode(val):
    arr = numpy.zeros((6,), dtype=int)
    arr[val] = 1
    return arr

def get_bucket_id(age):
  age_floor = int(age)
  if age_floor >= 0 and age_floor <= 5: return 0
  elif age_floor >= 6 and age_floor <= 12: return 1
  elif age_floor >= 13 and age_floor <= 19: return 2
  elif age_floor >= 20 and age_floor <= 29: return 3
  elif age_floor >= 30 and age_floor <= 59: return 4
  else: return 5

def get_ground_truth(age):
  return one_hot_encode(get_bucket_id(age))

# %%
def train(dataloader, model, loss_fn, optimizer):
    torch.cuda.empty_cache()
    size = len(dataloader.dataset)
    model.train()
    loss_tot = 0.0
    num = 0
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
      
        # Forward
        pred = model(X)
        loss = loss_fn(pred,y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_tot += loss.item()
        num += 1
        
        X.cpu()
        y.cpu()

    # loss_tot /= num
    print(f'training loss: {(loss_tot):>0.5f}')

# %%
validation_accuracy = []
current_max_val_acc = 0.0
def validation(dataloader, model, loss_fn):
    global current_max_val_acc
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    correct = 0
    totalsize = 0
    loss_tot = 0.0
    num = 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred,y)
            correct += (pred.argmax(1) == y.argmax(1)).sum().item()
            totalsize += pred.shape[0]
            loss_tot += loss.item()
            num += 1
            X.cpu()
            y.cpu()
            
    print(f"Correct/Total: {correct}/{totalsize}")
    correct /= totalsize
    validation_accuracy.append(correct*100)
    print(f"Validation Loss:  {(loss_tot):>0.5f}")
    print(f"Validation Accuracy: {(100*correct):>0.5f}%\n")
    current_max_val_acc = max(current_max_val_acc,100*correct)
    print(f"Current Best Validation Accuracy: {(current_max_val_acc):>0.5f}%\n")
    return loss_tot

# %%
class XRayToothDataset(Dataset):
    def __init__(self, cwd, img_dir, transform=None, target_height=None, target_width=None):
        self.dataset_path = cwd + '/' + img_dir
        self.transform = transform
        self.target_height = target_height
        self.target_width = target_width

    def __len__(self):
        return len(os.listdir(self.dataset_path))

    def __getitem__(self, idx):
        if idx  >= len(os.listdir(self.dataset_path)):
            print("No datafile/image at index : "+ str(idx))
            return None
        img_filename = os.listdir(self.dataset_path)[idx]
        age = float(img_filename.split("_")[1][:-4])
        age_gt = get_ground_truth(age)
        image_tensor = read_image(path=self.dataset_path + '/' + img_filename)
        image_tensor = image_tensor.reshape(1, 3, image_tensor.shape[-2], image_tensor.shape[-1])
        if self.target_height and self.target_width: # Resize the image 
            image_tensor = torch.nn.functional.interpolate(image_tensor, (self.target_height,self.target_width))
        if self.transform: image_tensor = self.transform(image_tensor) # Apply transformations
        image_tensor = (image_tensor-image_tensor.min())/(image_tensor.max()-image_tensor.min())
        return image_tensor.reshape(-1,image_tensor.shape[-2],image_tensor.shape[-1]).to(torch.float32), torch.tensor(age_gt)

# %%
training_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/training', transform=None, target_height=384, target_width=384)
validation_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/validation', transform=None, target_height=384, target_width=384)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3),

            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3),

            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3),

            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3),
            
            nn.Conv2d(in_channels=256, out_channels=280, kernel_size=2),
            nn.ReLU(),

            nn.Flatten(),
        )

        self.fc = nn.Sequential(
            nn.Linear(2520,512),
            nn.ReLU(),
            nn.Linear(512,128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128,6),
            nn.Softmax(dim=1)
        )
    
    def forward(self, x):
        x = self.features(x)
        x = self.fc(x)
        return x

# %%
model = NeuralNetwork().to(device)

# %%
# Test a forward pass
with torch.no_grad():
    print(model(training_data[0][0].reshape(-1,3,384,384).to(device)))
# Out:
# tensor([[0.1510, 0.1637, 0.1712, 0.1716, 0.1719, 0.1706]], device='cuda:0')

# %%
# Training Hyperparameters
epochs = 100
batch_size = 50
learning_rate = 1e-2
momentum=0.9

# %%
training_data_loader = DataLoader(training_data, batch_size, shuffle = True)
validation_data_loader = DataLoader(validation_data, batch_size, shuffle = False)

# %%
class CustomNLLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, predicted, ground_truth):
        indices = torch.argmax(ground_truth, dim=1)
        selected_probs = torch.gather(predicted, 1, indices.view(-1, 1))
        loss = -torch.log(selected_probs).mean()
        return loss

# %%
loss_function=CustomNLLoss()
optimizer=torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=5, min_lr=1e-8,verbose=True)

# %%
# Training
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data_loader, model, loss_function, optimizer)
    val_loss = validation(validation_data_loader, model, loss_function)
    scheduler.step(val_loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# training loss: 19.00438
# Correct/Total: 28/129
# Validation Loss:  4.52852
# Validation Accuracy: 21.70543%
#
# Current Best Validation Accuracy: 21.70543%
#
# Epoch 2
# -------------------------------
# training loss: 8.66814
# Correct/Total: 67/129
# Validation Loss:  4.27761
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 3
# -------------------------------
# training loss: 8.55086
# Correct/Total: 67/129
# Validation Loss:  4.48699
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 4
# -------------------------------
# training loss: 8.88650
# Correct/Total: 65/129
# Validation Loss:  4.26235
# Validation Accuracy: 50.38760%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 5
# -------------------------------
# training loss: 8.61130
# Correct/Total: 67/129
# Validation Loss:  4.16369
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 6
# -------------------------------
# training loss: 8.27004
# Correct/Total: 67/129
# Validation Loss:  4.13343
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 7
# -------------------------------
# training loss: 8.41895
# Correct/Total: 67/129
# Validation Loss:  4.14973
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 8
# -------------------------------
# training loss: 8.30794
# Correct/Total: 67/129
# Validation Loss:  4.10386
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 9
# -------------------------------
# training loss: 8.21493
# Correct/Total: 67/129
# Validation Loss:  4.09005
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 10
# -------------------------------
# training loss: 8.25429
# Correct/Total: 67/129
# Validation Loss:  4.01097
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 11
# -------------------------------
# training loss: 7.98530
# Correct/Total: 67/129
# Validation Loss:  4.05726
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 12
# -------------------------------
# training loss: 8.11618
# Correct/Total: 67/129
# Validation Loss:  4.10572
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 13
# -------------------------------
# training loss: 7.79924
# Correct/Total: 67/129
# Validation Loss:  3.81648
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 51.93798%
#
# Epoch 14
# -------------------------------
# training loss: 7.63649
# Correct/Total: 69/129
# Validation Loss:  3.81127
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 53.48837%
#
# Epoch 15
# -------------------------------
# training loss: 7.52537
# Correct/Total: 69/129
# Validation Loss:  3.82723
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 53.48837%
#
# Epoch 16
# -------------------------------
# training loss: 7.61251
# Correct/Total: 71/129
# Validation Loss:  3.90859
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 55.03876%
#
# Epoch 17
# -------------------------------
# training loss: 7.55041
# Correct/Total: 65/129
# Validation Loss:  3.81767
# Validation Accuracy: 50.38760%
#
# Current Best Validation Accuracy: 55.03876%
#
# Epoch 18
# -------------------------------
# training loss: 7.39922
# Correct/Total: 69/129
# Validation Loss:  3.72407
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 55.03876%
#
# Epoch 19
# -------------------------------
# training loss: 7.26117
# Correct/Total: 59/129
# Validation Loss:  3.89169
# Validation Accuracy: 45.73643%
#
# Current Best Validation Accuracy: 55.03876%
#
# Epoch 20
# -------------------------------
# training loss: 7.27463
# Correct/Total: 66/129
# Validation Loss:  3.69475
# Validation Accuracy: 51.16279%
#
# Current Best Validation Accuracy: 55.03876%
#
# Epoch 21
# -------------------------------
# training loss: 7.17713
# Correct/Total: 66/129
# Validation Loss:  3.66938
# Validation Accuracy: 51.16279%
#
# Current Best Validation Accuracy: 55.03876%
#
# Epoch 22
# -------------------------------
# training loss: 6.88774
# Correct/Total: 69/129
# Validation Loss:  3.78745
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 55.03876%
#
# Epoch 23
# -------------------------------
# training loss: 7.18757
# Correct/Total: 67/129
# Validation Loss:  3.64755
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 55.03876%
#
# Epoch 24
# -------------------------------
# training loss: 6.67969
# Correct/Total: 74/129
# Validation Loss:  3.58777
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 25
# -------------------------------
# training loss: 6.97574
# Correct/Total: 68/129
# Validation Loss:  3.54577
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 26
# -------------------------------
# training loss: 6.92516
# Correct/Total: 69/129
# Validation Loss:  3.40351
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 27
# -------------------------------
# training loss: 6.61625
# Correct/Total: 63/129
# Validation Loss:  3.55921
# Validation Accuracy: 48.83721%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 28
# -------------------------------
# training loss: 6.58938
# Correct/Total: 70/129
# Validation Loss:  3.39731
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 29
# -------------------------------
# training loss: 6.49577
# Correct/Total: 70/129
# Validation Loss:  3.46107
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 30
# -------------------------------
# training loss: 6.29493
# Correct/Total: 68/129
# Validation Loss:  3.74080
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 31
# -------------------------------
# training loss: 6.32777
# Correct/Total: 68/129
# Validation Loss:  3.41748
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 32
# -------------------------------
# training loss: 6.20804
# Correct/Total: 69/129
# Validation Loss:  3.53049
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 33
# -------------------------------
# training loss: 6.18284
# Correct/Total: 68/129
# Validation Loss:  3.45324
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 34
# -------------------------------
# training loss: 6.26159
# Correct/Total: 70/129
# Validation Loss:  3.42081
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 00034: reducing learning rate of group 0 to 1.0000e-03.
# Epoch 35
# -------------------------------
# training loss: 6.00115
# Correct/Total: 71/129
# Validation Loss:  3.37697
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 36
# -------------------------------
# training loss: 5.72230
# Correct/Total: 70/129
# Validation Loss:  3.37800
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 37
# -------------------------------
# training loss: 5.72930
# Correct/Total: 67/129
# Validation Loss:  3.40022
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 38
# -------------------------------
# training loss: 5.77861
# Correct/Total: 69/129
# Validation Loss:  3.38037
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 39
# -------------------------------
# training loss: 5.53956
# Correct/Total: 69/129
# Validation Loss:  3.35819
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 40
# -------------------------------
# training loss: 5.37678
# Correct/Total: 68/129
# Validation Loss:  3.39082
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 41
# -------------------------------
# training loss: 5.33493
# Correct/Total: 69/129
# Validation Loss:  3.39404
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 42
# -------------------------------
# training loss: 5.35911
# Correct/Total: 67/129
# Validation Loss:  3.40326
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 43
# -------------------------------
# training loss: 5.35942
# Correct/Total: 70/129
# Validation Loss:  3.38366
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 44
# -------------------------------
# training loss: 5.20263
# Correct/Total: 68/129
# Validation Loss:  3.42240
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 45
# -------------------------------
# training loss: 5.34393
# Correct/Total: 68/129
# Validation Loss:  3.44389
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 00045: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 46
# -------------------------------
# training loss: 5.10247
# Correct/Total: 68/129
# Validation Loss:  3.44448
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 47
# -------------------------------
# training loss: 5.14270
# Correct/Total: 68/129
# Validation Loss:  3.44545
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 48
# -------------------------------
# training loss: 5.00876
# Correct/Total: 68/129
# Validation Loss:  3.45145
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 49
# -------------------------------
# training loss: 4.85198
# Correct/Total: 68/129
# Validation Loss:  3.45763
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 50
# -------------------------------
# training loss: 5.03405
# Correct/Total: 68/129
# Validation Loss:  3.46507
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 51
# -------------------------------
# training loss: 5.16494
# Correct/Total: 68/129
# Validation Loss:  3.46762
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 00051: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 52
# -------------------------------
# training loss: 5.14009
# Correct/Total: 68/129
# Validation Loss:  3.46799
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 53
# -------------------------------
# training loss: 4.83990
# Correct/Total: 68/129
# Validation Loss:  3.46859
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 54
# -------------------------------
# training loss: 5.06952
# Correct/Total: 68/129
# Validation Loss:  3.46917
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 55
# -------------------------------
# training loss: 5.07200
# Correct/Total: 68/129
# Validation Loss:  3.46956
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 56
# -------------------------------
# training loss: 5.20720
# Correct/Total: 68/129
# Validation Loss:  3.46971
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 57
# -------------------------------
# training loss: 5.11381
# Correct/Total: 68/129
# Validation Loss:  3.46976
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 00057: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 58
# -------------------------------
# training loss: 5.13630
# Correct/Total: 68/129
# Validation Loss:  3.46981
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 59
# -------------------------------
# training loss: 5.04010
# Correct/Total: 68/129
# Validation Loss:  3.46982
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 60
# -------------------------------
# training loss: 5.00986
# Correct/Total: 68/129
# Validation Loss:  3.46987
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 61
# -------------------------------
# training loss: 4.99208
# Correct/Total: 68/129
# Validation Loss:  3.46994
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 62
# -------------------------------
# training loss: 5.25201
# Correct/Total: 68/129
# Validation Loss:  3.47000
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 63
# -------------------------------
# training loss: 5.26141
# Correct/Total: 68/129
# Validation Loss:  3.47003
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 00063: reducing learning rate of group 0 to 1.0000e-07.
# Epoch 64
# -------------------------------
# training loss: 5.09381
# Correct/Total: 68/129
# Validation Loss:  3.47004
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 65
# -------------------------------
# training loss: 5.15697
# Correct/Total: 68/129
# Validation Loss:  3.47004
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 66
# -------------------------------
# training loss: 4.94095
# Correct/Total: 68/129
# Validation Loss:  3.47004
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 67
# -------------------------------
# training loss: 4.99780
# Correct/Total: 68/129
# Validation Loss:  3.47004
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 68
# -------------------------------
# training loss: 4.99087
# Correct/Total: 68/129
# Validation Loss:  3.47004
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 69
# -------------------------------
# training loss: 5.03428
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 00069: reducing learning rate of group 0 to 1.0000e-08.
# Epoch 70
# -------------------------------
# training loss: 5.14627
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 71
# -------------------------------
# training loss: 5.19775
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 72
# -------------------------------
# training loss: 5.06785
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 73
# -------------------------------
# training loss: 5.23861
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 74
# -------------------------------
# training loss: 5.17416
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 75
# -------------------------------
# training loss: 5.06077
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 76
# -------------------------------
# training loss: 4.90313
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 77
# -------------------------------
# training loss: 5.05480
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 78
# -------------------------------
# training loss: 4.94193
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 79
# -------------------------------
# training loss: 4.98796
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 80
# -------------------------------
# training loss: 5.07218
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 81
# -------------------------------
# training loss: 4.99198
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 82
# -------------------------------
# training loss: 5.06580
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 83
# -------------------------------
# training loss: 5.04269
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 84
# -------------------------------
# training loss: 5.08927
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 85
# -------------------------------
# training loss: 5.06901
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 86
# -------------------------------
# training loss: 4.93078
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 87
# -------------------------------
# training loss: 5.11867
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 88
# -------------------------------
# training loss: 5.03984
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 89
# -------------------------------
# training loss: 5.09507
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 90
# -------------------------------
# training loss: 5.03360
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 91
# -------------------------------
# training loss: 5.11375
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 92
# -------------------------------
# training loss: 5.06944
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 93
# -------------------------------
# training loss: 5.02654
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 94
# -------------------------------
# training loss: 5.04713
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 95
# -------------------------------
# training loss: 4.97260
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 96
# -------------------------------
# training loss: 5.15339
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 97
# -------------------------------
# training loss: 5.12216
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 98
# -------------------------------
# training loss: 5.22283
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 99
# -------------------------------
# training loss: 4.97340
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Epoch 100
# -------------------------------
# training loss: 5.11274
# Correct/Total: 68/129
# Validation Loss:  3.47005
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 57.36434%
#
# Done!

# %%
plt.plot(validation_accuracy)
