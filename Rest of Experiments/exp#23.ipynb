# %%
import os
import json
import zipfile
import subprocess
import shutil
import getpass
import math
import numpy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image,ImageReadMode
import matplotlib.pyplot as plt

# %%
torch.manual_seed(20)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
# device = "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
dataset_save_dir = './dataset'

# %%
def one_hot_encode(val):
    arr = numpy.zeros((6,), dtype=int)
    arr[val] = 1
    return arr

def get_bucket_id(age):
  age_floor = int(age)
  if age_floor >= 0 and age_floor <= 5: return 0
  elif age_floor >= 6 and age_floor <= 12: return 1
  elif age_floor >= 13 and age_floor <= 19: return 2
  elif age_floor >= 20 and age_floor <= 29: return 3
  elif age_floor >= 30 and age_floor <= 59: return 4
  else: return 5

def get_ground_truth(age):
  return one_hot_encode(get_bucket_id(age))

# %%
def train(dataloader, model, loss_fn, optimizer):
    torch.cuda.empty_cache()
    size = len(dataloader.dataset)
    model.train()
    loss_tot = 0.0
    num = 0
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
      
        # Forward
        pred = model(X)
        # predSoftmax = nn.Softmax(dim=1)(pred)
        loss = loss_fn(pred,y)

        # print(loss.item())

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_tot += loss.item()
        num += 1
        
        X.cpu()
        y.cpu()

    # loss_tot /= num
    print(f'training loss: {(loss_tot):>0.5f}')

# %%
validation_accuracy = []
current_max_val_acc = 0.0
def validation(dataloader, model, loss_fn):
    global current_max_val_acc
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    correct = 0
    totalsize = 0
    loss_tot = 0.0
    num = 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            # predSoftmax = nn.Softmax(dim=1)(pred)
            loss = loss_fn(pred,y)
            correct += (pred.argmax(1) == y.argmax(1)).sum().item()
            totalsize += pred.shape[0]
            loss_tot += loss.item()
            num += 1
            X.cpu()
            y.cpu()
            
    print(f"Correct/Total: {correct}/{totalsize}")
    correct /= totalsize
    validation_accuracy.append(correct*100)
    print(f"Validation Loss:  {(loss_tot):>0.5f}")
    print(f"Validation Accuracy: {(100*correct):>0.5f}%\n")
    current_max_val_acc = max(current_max_val_acc,100*correct)
    print(f"Current Best Validation Accuracy: {(current_max_val_acc):>0.5f}%\n")
    return loss_tot

# %%
class XRayToothDataset(Dataset):
    def __init__(self, cwd, img_dir, transform=None, target_height=None, target_width=None):
        self.dataset_path = cwd + '/' + img_dir
        self.transform = transform
        self.target_height = target_height
        self.target_width = target_width

    def __len__(self):
        return len(os.listdir(self.dataset_path))

    def __getitem__(self, idx):
        if idx  >= len(os.listdir(self.dataset_path)):
            print("No datafile/image at index : "+ str(idx))
            return None
        img_filename = os.listdir(self.dataset_path)[idx]
        age = float(img_filename.split("_")[1][:-4])
        age_gt = get_ground_truth(age)
        image_tensor = read_image(path=self.dataset_path + '/' + img_filename)
        image_tensor = image_tensor.reshape(1, 3, image_tensor.shape[-2], image_tensor.shape[-1])
        if self.target_height and self.target_width: # Resize the image 
            image_tensor = torch.nn.functional.interpolate(image_tensor, (self.target_height,self.target_width))
        if self.transform: image_tensor = self.transform(image_tensor) # Apply transformations
        image_tensor = (image_tensor-image_tensor.min())/(image_tensor.max()-image_tensor.min())
        return image_tensor.reshape(-1,image_tensor.shape[-2],image_tensor.shape[-1]).to(torch.float32), torch.tensor(age_gt)

# %%
training_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/training', transform=None, target_height=384, target_width=384)
validation_data = XRayToothDataset(os.getcwd(), img_dir=dataset_save_dir+'/validation', transform=None, target_height=384, target_width=384)

# %%
from torchvision.models import vit_b_16, ViT_B_16_Weights

pretrained_vit = vit_b_16(weights=ViT_B_16_Weights.IMAGENET1K_SWAG_E2E_V1)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = pretrained_vit

        for param in self.backbone.parameters():
            param.requires_grad = False

        self.fc = nn.Sequential(
            nn.Dropout(0.7),
            nn.Linear(1000,6)
        )
    
    def forward(self, x):
        x = self.backbone(x)
        x = self.fc(x)
        return x

# %%
model = NeuralNetwork().to(device)

# %%
# Test a forward pass
with torch.no_grad():
    print(model(training_data[0][0].reshape(-1,3,384,384).to(device)))
# Out:
# tensor([[-0.9772,  0.8741,  0.9757,  0.1515,  1.0241, -0.6456]],
#        device='cuda:0')

# %%
# Training Hyperparameters
epochs = 200
batch_size = 10
learning_rate = 1e-2
momentum=0.9

# %%
training_data_loader = DataLoader(training_data, batch_size, shuffle = True)
validation_data_loader = DataLoader(validation_data, batch_size, shuffle = False)

# %%
class CustomNLLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, predicted, ground_truth):
        indices = torch.argmax(ground_truth, dim=1)
        loss = torch.nn.functional.cross_entropy(predicted, indices)
        # selected_probs = torch.gather(predicted, 1, indices.view(-1, 1))
        # loss = -torch.log(selected_probs).mean()
        return loss

# %%
loss_function=CustomNLLoss()
optimizer=torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=5, min_lr=1e-4,verbose=True)

# %%
# Training
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data_loader, model, loss_function, optimizer)
    val_loss = validation(validation_data_loader, model, loss_function)
    scheduler.step(val_loss)
    # torch.save(model, 'model.pth')
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# training loss: 35.29299
# Correct/Total: 72/129
# Validation Loss:  24.37018
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 2
# -------------------------------
# training loss: 35.30292
# Correct/Total: 76/129
# Validation Loss:  25.43788
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 00202: reducing learning rate of group 0 to 5.2335e-04.
# Epoch 3
# -------------------------------
# training loss: 39.87324
# Correct/Total: 74/129
# Validation Loss:  24.27319
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 4
# -------------------------------
# training loss: 43.00424
# Correct/Total: 70/129
# Validation Loss:  24.39130
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 5
# -------------------------------
# training loss: 29.66228
# Correct/Total: 72/129
# Validation Loss:  24.88319
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 6
# -------------------------------
# training loss: 35.51422
# Correct/Total: 70/129
# Validation Loss:  25.01214
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 7
# -------------------------------
# training loss: 34.32402
# Correct/Total: 71/129
# Validation Loss:  24.19169
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 8
# -------------------------------
# training loss: 35.94861
# Correct/Total: 74/129
# Validation Loss:  24.09782
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 00208: reducing learning rate of group 0 to 4.7101e-04.
# Epoch 9
# -------------------------------
# training loss: 38.42121
# Correct/Total: 72/129
# Validation Loss:  24.71277
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 10
# -------------------------------
# training loss: 40.77561
# Correct/Total: 75/129
# Validation Loss:  25.42139
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 11
# -------------------------------
# training loss: 36.07415
# Correct/Total: 73/129
# Validation Loss:  24.82204
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 12
# -------------------------------
# training loss: 34.80928
# Correct/Total: 73/129
# Validation Loss:  22.56831
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 13
# -------------------------------
# training loss: 37.29593
# Correct/Total: 72/129
# Validation Loss:  22.68176
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 14
# -------------------------------
# training loss: 34.53102
# Correct/Total: 74/129
# Validation Loss:  24.32870
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 15
# -------------------------------
# training loss: 40.81863
# Correct/Total: 74/129
# Validation Loss:  23.58697
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 16
# -------------------------------
# training loss: 39.34183
# Correct/Total: 66/129
# Validation Loss:  24.65191
# Validation Accuracy: 51.16279%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 17
# -------------------------------
# training loss: 36.01590
# Correct/Total: 70/129
# Validation Loss:  25.43222
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 18
# -------------------------------
# training loss: 32.90022
# Correct/Total: 73/129
# Validation Loss:  21.85743
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 19
# -------------------------------
# training loss: 30.21911
# Correct/Total: 64/129
# Validation Loss:  23.45071
# Validation Accuracy: 49.61240%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 20
# -------------------------------
# training loss: 43.33643
# Correct/Total: 72/129
# Validation Loss:  22.50061
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 21
# -------------------------------
# training loss: 38.28683
# Correct/Total: 67/129
# Validation Loss:  24.73858
# Validation Accuracy: 51.93798%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 22
# -------------------------------
# training loss: 36.56717
# Correct/Total: 66/129
# Validation Loss:  25.18615
# Validation Accuracy: 51.16279%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 23
# -------------------------------
# training loss: 37.62921
# Correct/Total: 74/129
# Validation Loss:  24.54897
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 24
# -------------------------------
# training loss: 38.28335
# Correct/Total: 76/129
# Validation Loss:  25.00645
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 00224: reducing learning rate of group 0 to 4.2391e-04.
# Epoch 25
# -------------------------------
# training loss: 33.88208
# Correct/Total: 69/129
# Validation Loss:  22.70770
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 26
# -------------------------------
# training loss: 30.78664
# Correct/Total: 72/129
# Validation Loss:  25.67406
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 27
# -------------------------------
# training loss: 31.99982
# Correct/Total: 76/129
# Validation Loss:  25.60058
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 28
# -------------------------------
# training loss: 32.11794
# Correct/Total: 74/129
# Validation Loss:  24.01812
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 29
# -------------------------------
# training loss: 33.28877
# Correct/Total: 66/129
# Validation Loss:  24.19466
# Validation Accuracy: 51.16279%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 30
# -------------------------------
# training loss: 33.97865
# Correct/Total: 72/129
# Validation Loss:  23.68905
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 00230: reducing learning rate of group 0 to 3.8152e-04.
# Epoch 31
# -------------------------------
# training loss: 32.37767
# Correct/Total: 70/129
# Validation Loss:  24.86156
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 32
# -------------------------------
# training loss: 35.46742
# Correct/Total: 66/129
# Validation Loss:  24.08843
# Validation Accuracy: 51.16279%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 33
# -------------------------------
# training loss: 33.88729
# Correct/Total: 73/129
# Validation Loss:  23.04031
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 34
# -------------------------------
# training loss: 32.45338
# Correct/Total: 71/129
# Validation Loss:  22.80155
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 35
# -------------------------------
# training loss: 31.51675
# Correct/Total: 75/129
# Validation Loss:  23.45077
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 36
# -------------------------------
# training loss: 35.37616
# Correct/Total: 74/129
# Validation Loss:  23.78264
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 00236: reducing learning rate of group 0 to 3.4337e-04.
# Epoch 37
# -------------------------------
# training loss: 29.95579
# Correct/Total: 75/129
# Validation Loss:  23.78085
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 38
# -------------------------------
# training loss: 36.03386
# Correct/Total: 73/129
# Validation Loss:  23.51240
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 39
# -------------------------------
# training loss: 35.92744
# Correct/Total: 74/129
# Validation Loss:  22.92630
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 40
# -------------------------------
# training loss: 43.25388
# Correct/Total: 76/129
# Validation Loss:  24.68873
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 41
# -------------------------------
# training loss: 32.31724
# Correct/Total: 69/129
# Validation Loss:  23.00561
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 42
# -------------------------------
# training loss: 34.27128
# Correct/Total: 75/129
# Validation Loss:  23.28847
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 00242: reducing learning rate of group 0 to 3.0903e-04.
# Epoch 43
# -------------------------------
# training loss: 37.57156
# Correct/Total: 75/129
# Validation Loss:  23.37322
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 44
# -------------------------------
# training loss: 35.84789
# Correct/Total: 73/129
# Validation Loss:  24.32734
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 45
# -------------------------------
# training loss: 32.64952
# Correct/Total: 69/129
# Validation Loss:  23.30975
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 46
# -------------------------------
# training loss: 32.43237
# Correct/Total: 74/129
# Validation Loss:  23.16839
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 47
# -------------------------------
# training loss: 36.00961
# Correct/Total: 73/129
# Validation Loss:  22.45760
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 48
# -------------------------------
# training loss: 34.69876
# Correct/Total: 70/129
# Validation Loss:  23.29041
# Validation Accuracy: 54.26357%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 00248: reducing learning rate of group 0 to 2.7813e-04.
# Epoch 49
# -------------------------------
# training loss: 36.24311
# Correct/Total: 74/129
# Validation Loss:  22.67530
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 50
# -------------------------------
# training loss: 40.30927
# Correct/Total: 73/129
# Validation Loss:  22.46466
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 51
# -------------------------------
# training loss: 31.90117
# Correct/Total: 74/129
# Validation Loss:  22.03802
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 52
# -------------------------------
# training loss: 32.59072
# Correct/Total: 72/129
# Validation Loss:  23.62535
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 53
# -------------------------------
# training loss: 36.96211
# Correct/Total: 69/129
# Validation Loss:  23.72903
# Validation Accuracy: 53.48837%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 54
# -------------------------------
# training loss: 29.73716
# Correct/Total: 73/129
# Validation Loss:  22.97957
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 00254: reducing learning rate of group 0 to 2.5032e-04.
# Epoch 55
# -------------------------------
# training loss: 32.23005
# Correct/Total: 68/129
# Validation Loss:  23.08977
# Validation Accuracy: 52.71318%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 56
# -------------------------------
# training loss: 35.30730
# Correct/Total: 71/129
# Validation Loss:  22.89317
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 57
# -------------------------------
# training loss: 38.76179
# Correct/Total: 75/129
# Validation Loss:  23.76384
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 58
# -------------------------------
# training loss: 33.30474
# Correct/Total: 74/129
# Validation Loss:  22.81930
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 59
# -------------------------------
# training loss: 31.10226
# Correct/Total: 74/129
# Validation Loss:  23.37235
# Validation Accuracy: 57.36434%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 60
# -------------------------------
# training loss: 29.61325
# Correct/Total: 75/129
# Validation Loss:  23.26504
# Validation Accuracy: 58.13953%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 00260: reducing learning rate of group 0 to 2.2528e-04.
# Epoch 61
# -------------------------------
# training loss: 32.90320
# Correct/Total: 72/129
# Validation Loss:  23.07318
# Validation Accuracy: 55.81395%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 62
# -------------------------------
# training loss: 29.02369
# Correct/Total: 76/129
# Validation Loss:  23.15230
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 63
# -------------------------------
# training loss: 37.04432
# Correct/Total: 71/129
# Validation Loss:  23.28530
# Validation Accuracy: 55.03876%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 64
# -------------------------------
# training loss: 33.17412
# Correct/Total: 76/129
# Validation Loss:  23.00224
# Validation Accuracy: 58.91473%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 65
# -------------------------------
# training loss: 29.49091
# Correct/Total: 73/129
# Validation Loss:  23.16992
# Validation Accuracy: 56.58915%
#
# Current Best Validation Accuracy: 62.01550%
#
# Epoch 66
# -------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-291cab6f94cf> in <cell line: 2>()
#       2 for t in range(epochs):
#       3     print(f"Epoch {t+1}\n-------------------------------")
# ----> 4     train(training_data_loader, model, loss_function, optimizer)
#       5     val_loss = validation(validation_data_loader, model, loss_function)
#       6     scheduler.step(val_loss)
#
# <ipython-input-9-1aaf77e88ceb> in train(dataloader, model, loss_fn, optimizer)
#      20         optimizer.step()
#      21
# ---> 22         loss_tot += loss.item()
#      23         num += 1
#      24
#
# KeyboardInterrupt:

# %%
plt.plot(validation_accuracy)
